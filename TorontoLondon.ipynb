# %% [markdown]
# # Toronto vs. London neighborhoods

# %% [markdown]
# In this project I will assess the similarity between the cities of Toronto, Canada and London, Great Britain. This assessment could help someone that is moving between the two cities in deciding the neighbourhoods that are similar to the one where they currently live. Because I am using crime data in the analysis, this information can also help security companies pursue their customers from high crime rate neighbourhoods and can also be used by landlords in implementing extra security measures for the buildings that they own in order to increase safety in and around their building.

# %% [markdown]
# I have started collecting my data with web scraping wikipedia pages for the neighbourhood names in each city, then organising the information into data frames.
# For the crime information I have downloaded crime datasets for each city from the respective police stations and I have resumed it to a data frame containing the neighbourhood name and total crimes in the years 2015-2016 in each neighbourhood, for each city. Afterwards I have combined the resulting data frames and created a map visualisation of each neighbourhood with its respective crime rates.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim 

# !pip install geocoder
import geocoder

import json
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests 
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
from sklearn import preprocessing

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: geocoder in ./opt/anaconda3/lib/python3.8/site-packages (1.38.1)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (from geocoder) (2.24.0)
# Requirement already satisfied: future in ./opt/anaconda3/lib/python3.8/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: click in ./opt/anaconda3/lib/python3.8/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: ratelim in ./opt/anaconda3/lib/python3.8/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.8/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: decorator in ./opt/anaconda3/lib/python3.8/site-packages (from ratelim->geocoder) (4.4.2)
# Libraries imported.

# %% [markdown]
# ## Wrangling the crime data of the cities
# ### Toronto

# %%
# Viewing the crime data of Toronto, downloaded from the police website 
crimeT=pd.read_csv('/Users/Elena/Downloads/TorontoCrime.csv')
crimeT.head()
# Out:
# /Users/Elena/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               X             Y  Index_ event_unique_id Division  \
# 0 -8.859749e+06  5.423033e+06   10182  GO-20142103239      D23
# 1 -8.861050e+06  5.426864e+06   10298  GO-20142111528      D23
# 2 -8.861412e+06  5.422084e+06   10300  GO-20142111859      D23
# 3 -8.859955e+06  5.424372e+06   10345  GO-20142116041      D23
# 4 -8.859955e+06  5.424372e+06   10346  GO-20142116041      D23
#
#            occurrencedate            reporteddate premises_type  ucr_code  \
# 0  2014/05/18 04:00:00+00  2014/05/18 04:00:00+00         House      1430
# 1  2014/05/19 04:00:00+00  2014/05/19 04:00:00+00       Outside      1430
# 2  2014/05/19 04:00:00+00  2014/05/19 04:00:00+00     Apartment      2120
# 3  2014/05/20 04:00:00+00  2014/05/20 04:00:00+00       Outside      1420
# 4  2014/05/20 04:00:00+00  2014/05/20 04:00:00+00       Outside      1420
#
#    ucr_ext              offence  reportedyear reportedmonth  reportedday  \
# 0      100              Assault          2014           May           18
# 1      100              Assault          2014           May           19
# 2      200                  B&E          2014           May           19
# 3      100  Assault With Weapon          2014           May           20
# 4      110  Assault Bodily Harm          2014           May           20
#
#    reporteddayofyear reporteddayofweek  reportedhour  occurrenceyear  \
# 0                138            Sunday            12          2014.0
# 1                139            Monday            21          2014.0
# 2                139            Monday            22          2014.0
# 3                140           Tuesday            14          2014.0
# 4                140           Tuesday            14          2014.0
#
#   occurrencemonth  occurrenceday  occurrencedayofyear occurrencedayofweek  \
# 0             May           18.0                138.0              Sunday
# 1             May           19.0                139.0              Monday
# 2             May           19.0                139.0              Monday
# 3             May           20.0                140.0             Tuesday
# 4             May           20.0                140.0             Tuesday
#
#    occurrencehour              MCI Hood_ID               Neighbourhood  \
# 0              12          Assault       1  West Humber-Clairville (1)
# 1              20          Assault       1  West Humber-Clairville (1)
# 2              22  Break and Enter       1  West Humber-Clairville (1)
# 3              14          Assault       1  West Humber-Clairville (1)
# 4              14          Assault       1  West Humber-Clairville (1)
#
#         Long        Lat  ObjectId
# 0 -79.588477  43.725321         1
# 1 -79.600166  43.750187         2
# 2 -79.603420  43.719158         3
# 3 -79.590332  43.734013         4
# 4 -79.590332  43.734013         5

# %%
# Deleting the rows that are not necessary for the analysis. 
# I will be using the registered crimes for the years 2015-2016
crimeT=crimeT[crimeT['reportedyear']<=2016]
crimeT=crimeT[crimeT['reportedyear']>2014]

crimeT.drop(crimeT.iloc[:, 0:10], axis=1, inplace=True)
crimeT.drop(crimeT.iloc[:, 2:13], axis=1, inplace=True)
crimeT.drop(crimeT.iloc[:, 3:4], axis=1, inplace=True)
crimeT.drop(crimeT.iloc[:, 4:7], axis=1, inplace=True)

crimeT.head()
# Out:
#      offence  reportedyear      MCI               Neighbourhood
# 114  Assault          2015  Assault  West Humber-Clairville (1)
# 118  Assault          2015  Assault  West Humber-Clairville (1)
# 120  Assault          2015  Assault  West Humber-Clairville (1)
# 122  Assault          2015  Assault  West Humber-Clairville (1)
# 124  Assault          2015  Assault  West Humber-Clairville (1)

# %%
# Sorting the data by neighborhood
crimeT=crimeT['Neighbourhood'].value_counts()
crimeT=crimeT.to_frame().reset_index()
crimeT.columns=['Neighborhood', 'TotalCrimes']

split=pd.DataFrame()
split[['New1', 'New2']]=crimeT['Neighborhood'].str.split("(", 1, expand=True)

crimeT['Neighborhood']=split['New1']

crimeT=crimeT.sort_values('Neighborhood')
crimeT=crimeT.reset_index()
crimeT.drop(crimeT.iloc[:, 0:1], axis=1, inplace=True)

rowsC=crimeT.iloc[[28, 84, 116]]
rowsC

crimeT=crimeT.drop([crimeT.index[28], crimeT.index[84], crimeT.index[116]])
crimeT=crimeT.reset_index()
crimeT.drop(crimeT.iloc[:, 0:1], axis=1, inplace=True)

print("Shape of crimeT dataframe:", crimeT.shape)

crimeT.head()
# Out:
# Shape of crimeT dataframe: (138, 2)
#                     Neighborhood  TotalCrimes
# 0               Agincourt North           363
# 1  Agincourt South-Malvern West           478
# 2                     Alderwood           204
# 3                         Annex           943
# 4             Banbury-Don Mills           403

# %% [markdown]
# ### London

# %%
# Viewing the crime data of London, downloaded from the police website 
crimeL=pd.read_csv('/Users/Elena/Downloads/Crime_London.csv')
crimeL.head()
# Out:
#     WardCode       Ward Name               Borough Major Category  \
# 0  E05000026           Abbey  Barking and Dagenham       Burglary
# 1  E05000027          Alibon  Barking and Dagenham       Burglary
# 2  E05000028       Becontree  Barking and Dagenham       Burglary
# 3  E05000029  Chadwell Heath  Barking and Dagenham       Burglary
# 4  E05000030       Eastbrook  Barking and Dagenham       Burglary
#
#            Minor Category  201004  201005  201006  201007  201008  201009  \
# 0  Burglary In A Dwelling       9       4       6       6      12       5
# 1  Burglary In A Dwelling       7       3       8      12      12      14
# 2  Burglary In A Dwelling      10       6      21       7      13       8
# 3  Burglary In A Dwelling      10      10      11       8      13       7
# 4  Burglary In A Dwelling       3       5       2       6       4       4
#
#    201010  201011  201012  201101  201102  201103  201104  201105  201106  \
# 0       3      11       8       8       7       4       7      13       5
# 1       4       8       7       8       8      10      12       8       8
# 2       4      12       9      16       9      21      10       6       7
# 3      12      16       4      18       8      18       9       6       6
# 4       8       3       6      10       4       7       7       4       2
#
#    201107  201108  201109  201110  201111  201112  201201  201202  201203  \
# 0       4       5       8       8       7       7       9       6       5
# 1      11       9       5       3       9       4      11      15      17
# 2      10      10      15      10      13      12      18       3      14
# 3       7      13       7      10      11      15      14       9      13
# 4       3       4       6       8      16      14       9      10       8
#
#    201204  201205  201206  201207  201208  201209  201210  201211  201212  \
# 0       6       9       6       6       4       5       5      11       1
# 1      10       9       8       6       5       3       6       7       5
# 2      10      14       6      14      11       8      12      12      18
# 3      10      15       8      14      10       7      10      14      13
# 4       8      11       6       3       4       5       5       6       8
#
#    201301  201302  201303  201304  201305  201306  201307  201308  201309  \
# 0       6       9       9       1       6       4       5       5       2
# 1      10      14       4       2       6       3       3       2       1
# 2      13       9      12      20       9       7       5       4       7
# 3      13      10       8      11      10      10       5       8       7
# 4      11      10       5       8       8       5       7       3       2
#
#    201310  201311  201312  201401  201402  201403  201404  201405  201406  \
# 0       2       6       3       5       5       9       2       6       3
# 1       6       3       5       7       4      11       7       4       4
# 2      16      15      10       6       6       8       2      10      11
# 3      11      10       7      12       7       6       7       6       5
# 4       6       5       5       6       5       5       1       4       2
#
#    201407  201408  201409  201410  201411  201412  201501  201502  201503  \
# 0       4       2       2       1       6       5       0       7       1
# 1       5       5       0       6      10       7       9       4       5
# 2       6      13       9      11       8       9      19       7       2
# 3      11       6       5       7      13       6       6      10       9
# 4      13       4       8      10       8       7       6       0       6
#
#    201504  201505  201506  201507  201508  201509  201510  201511  201512  \
# 0       7       4       2       2       6       3       2       7       3
# 1       3       1       1       5       2       5       4       3       8
# 2       5       8       2       7       5       6      10       3       9
# 3       3       2       7       7       6       4       6      12      10
# 4       0       2       5       5       5       3       4       5       7
#
#    201601  201602  201603  201604  201605  201606  201607  201608  201609  \
# 0       4       6       5       2       2      10       3       2       3
# 1       6       5       7       2       5       4       5       0       0
# 2       8       7       6       4       2       6       4       4       4
# 3       7       3       4       1       7       2       5       2       4
# 4       5       7       1       3       3       1       4       2       7
#
#    201610  201611  201612  201701  201702  201703  201704  201705  201706  \
# 0       1       3       3       3       1       7      12      12       3
# 1       2       2       5       4       8       3       5       5      11
# 2       4       6       5      12      15       4       5      14       5
# 3       3       4      11      10       6       7       7       4       2
# 4       8       2       7       2       4       7       2       8       3
#
#    201707  201708  201709  201710  201711  201712  201801  201802  201803  \
# 0       5       4       3       3       4       3       7       6       8
# 1       9       4       0       4       1       1       8       8       7
# 2      10       5       7      15       5      11       7       6       7
# 3       2       4       3       5       4      11      12      10       7
# 4       5       3       5       3       3       2      11       2       5
#
#    201804  201805  201806  201807  201808  201809  201810  201811  201812
# 0       5       5       4       6       3       6       6       4       8
# 1       1       5       3       2       4       4       8       4      10
# 2       8       6       4       7       3       6       5      10       9
# 3       5       8       6       5       4       8       5      10       8
# 4       2       1       2       3       3       6       6      11       2

# %%
# Deleting the columns that are not necessary for the analysis. 
# I will be using the registered crimes for the years 2015-2016
crimeL.drop(crimeL.iloc[:, 5:62], axis=1, inplace=True)
crimeL.drop(crimeL.iloc[:, 29:56], axis=1, inplace=True)
crimeL.drop(crimeL.iloc[:, 0:1], axis=1, inplace=True)
crimeL.drop(crimeL.iloc[:, 2:4], axis=1, inplace=True)

# Creating a new column for the total number of crimes in 2015 and 2016
crimeL['TotalCrimes']=crimeL.iloc[:, 2:26].sum(axis=1)
crimeL.drop(crimeL.iloc[:, 2:26], axis=1, inplace=True)

crimeL.columns=['Neighborhood', 'Borough', 'TotalCrimes']
crimeL.head()
# Out:
#      Neighborhood               Borough  TotalCrimes
# 0           Abbey  Barking and Dagenham           88
# 1          Alibon  Barking and Dagenham           93
# 2       Becontree  Barking and Dagenham          143
# 3  Chadwell Heath  Barking and Dagenham          135
# 4       Eastbrook  Barking and Dagenham           98

# %%
# Organizing the data by neighborhood (before it was organized by type of crime)
crimeL=crimeL.groupby(['Neighborhood', 'Borough']).sum()
crimeL=crimeL.reset_index()
crimeL.head()
# Out:
#   Neighborhood                 Borough  TotalCrimes
# 0        Abbey    Barking and Dagenham         4334
# 1        Abbey                  Merton         1448
# 2   Abbey Road             Westminster         1215
# 3   Abbey Wood               Greenwich         2640
# 4     Abingdon  Kensington and Chelsea         1771

# %% [markdown]
# ## Webscraping for the neighborhoods of the cities
# ### Toronto

# %%
# Webscraping the wikipedia page for the neighborhoods of Toronto
url = 'https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto#Table'
r=requests.get(url)
toronto_list= pd.read_html(r.text)
Toronto=toronto_list[10]
Toronto.drop(Toronto.iloc[:, 3:6], axis=1, inplace=True)
Toronto.drop(Toronto.iloc[:, 0:1], axis=1, inplace=True)
Toronto.columns=['Neighborhood', 'Borough']

Toronto=Toronto.drop([Toronto.index[28], Toronto.index[30]])
Toronto=Toronto.reset_index()
Toronto.drop(Toronto.iloc[:, 0:1], axis=1, inplace=True)

print("Shape of Toronto dataframe:", Toronto.shape)

Toronto.head()
# Out:
# Shape of Toronto dataframe: (138, 2)
#                    Neighborhood              Borough
# 0               Agincourt North          Scarborough
# 1  Agincourt South-Malvern West          Scarborough
# 2                     Alderwood            Etobicoke
# 3                         Annex  Old City of Toronto
# 4             Banbury-Don Mills           North York

# %% [markdown]
# ### London

# %%
# Webscraping the wikipedia page for the neighborhoods of London
url = 'https://en.wikipedia.org/wiki/List_of_areas_of_London'
r=requests.get(url)
london_list= pd.read_html(r.text)
London=london_list[1]
print("Shape of data frame:", London.shape)
London.head()
# Out:
# Shape of data frame: (531, 6)
#       Location                     London borough       Post town  \
# 0   Abbey Wood              Bexley, Greenwich [7]          LONDON
# 1        Acton  Ealing, Hammersmith and Fulham[8]          LONDON
# 2    Addington                         Croydon[8]         CROYDON
# 3   Addiscombe                         Croydon[8]         CROYDON
# 4  Albany Park                             Bexley  BEXLEY, SIDCUP
#
#   Postcode district Dial code OS grid ref
# 0               SE2       020    TQ465785
# 1            W3, W4       020    TQ205805
# 2               CR0       020    TQ375645
# 3               CR0       020    TQ345665
# 4         DA5, DA14       020    TQ478728

# %%
# Organizing the data and leaving only the neighborhood and borough columns
London.columns=['Neighborhood', 'Borough', 'PostTown', 'PostCode', 'Dial', 'OS']
London=London.drop(['PostTown','PostCode','Dial', 'OS'], axis=1)

split=pd.DataFrame()
split[['New1', 'New2']]=London['Borough'].str.split("[", 1, expand=True)
London['Borough']=split['New1']

London.head()
# Out:
#   Neighborhood                         Borough
# 0   Abbey Wood              Bexley, Greenwich
# 1        Acton  Ealing, Hammersmith and Fulham
# 2    Addington                         Croydon
# 3   Addiscombe                         Croydon
# 4  Albany Park                          Bexley

# %% [markdown]
# ## Merging the crime data with the neighborhoods and boroughs then getting the neighborhoods coordinates
# ### Toronto

# %%
# Merging the Toronto neighborhood data with the crime data
dfToronto=pd.merge(crimeT, Toronto, right_index=True, left_index=True)
dfToronto.drop(dfToronto.iloc[:, 0:1], axis=1, inplace=True)
dfToronto.columns=['TotalCrimes', 'Neighborhood', 'Borough']

dfToronto=dfToronto.filter(['Neighborhood', 'Borough', 'TotalCrimes'])
print("Shape of the final dfToronto:", dfToronto.shape)
dfToronto.head()
# Out:
# Shape of the final dfToronto: (138, 3)
#                    Neighborhood              Borough  TotalCrimes
# 0               Agincourt North          Scarborough          363
# 1  Agincourt South-Malvern West          Scarborough          478
# 2                     Alderwood            Etobicoke          204
# 3                         Annex  Old City of Toronto          943
# 4             Banbury-Don Mills           North York          403

# %%
neighborhood = dfToronto['Neighborhood']

# Empty lists that will store the coordinates information from the geocoder
latitude = []
longitude = []
n = 0

# Loop that keeps on trying to get the latitude and longitude for each neighborhood until it succeedes
while n < len(neighborhood):
    g = geocoder.arcgis('{}, Toronto, Ontario'.format(neighborhood[n]))
    lat_lng_coords = g.latlng
    print('The geograpical coordinate of {} are {}, {}.'.format(neighborhood[n], lat_lng_coords[0], lat_lng_coords[1]))
    latitude.append(lat_lng_coords[0])
    longitude.append(lat_lng_coords[1])
    n = n + 1

dfToronto['Longitude'] = longitude
dfToronto['Latitude'] = latitude
dfToronto.head()
# Out:
# The geograpical coordinate of Agincourt North are 43.809300000000064, -79.26706999999999.
# The geograpical coordinate of Agincourt South-Malvern West are 43.787360000000035, -79.26934999999997.
# The geograpical coordinate of Alderwood are 43.60496000000006, -79.54115999999993.
# The geograpical coordinate of Annex are 43.66936000000004, -79.40279999999996.
# The geograpical coordinate of Banbury-Don Mills are 43.740410000000054, -79.34851999999995.
# The geograpical coordinate of Bathurst Manor are 43.763780000000054, -79.45476999999994.
# The geograpical coordinate of Bay Street Corridor are 43.657710000000066, -79.38617999999997.
# The geograpical coordinate of Bayview Village are 43.777100000000075, -79.37956999999994.
# The geograpical coordinate of Bayview Woods-Steeles are 43.794850000000054, -79.38221999999996.
# The geograpical coordinate of Bedford Park-Nortown are 43.73066000000006, -79.42449999999997.
# The geograpical coordinate of Beechborough-Greenbrook are 43.69311000000005, -79.47830999999996.
# The geograpical coordinate of Bendale are 43.75963000000007, -79.25738999999999.
# The geograpical coordinate of Birchcliffe-Cliffside are 43.694720000000075, -79.26459999999997.
# The geograpical coordinate of Black Creek are 43.76636000000008, -79.52149999999995.
# The geograpical coordinate of Blake-Jones are 43.67522000000008, -79.33761999999996.
# The geograpical coordinate of Briar Hill-Belgravia are 43.69852000000003, -79.45124999999996.
# The geograpical coordinate of Bridle Path-Sunnybrook-York Mills are 43.72732000000008, -79.38086999999996.
# The geograpical coordinate of Broadview North are 43.68937000000005, -79.35428999999993.
# The geograpical coordinate of Brookhaven-Amesbury are 43.70031000000006, -79.48464999999999.
# The geograpical coordinate of Cabbagetown-South St. James Town are 43.66760000000005, -79.36418999999995.
# The geograpical coordinate of Caledonia-Fairbank are 43.68857000000003, -79.45482999999996.
# The geograpical coordinate of Casa Loma are 43.68078000000003, -79.40948999999995.
# The geograpical coordinate of Centennial Scarborough are 43.77914000000004, -79.14724999999999.
# The geograpical coordinate of Church-Yonge Corridor are 43.660240000000044, -79.37867999999997.
# The geograpical coordinate of Clairlea-Birchmount are 43.716080000000034, -79.28313999999995.
# The geograpical coordinate of Clanton Park are 43.74359000000004, -79.44320999999997.
# The geograpical coordinate of Cliffcrest are 43.726420000000076, -79.23296999999997.
# The geograpical coordinate of Corso Italia-Davenport are 43.676990000000046, -79.45037999999994.
# The geograpical coordinate of Danforth - East York are 43.69066965894869, -79.29079162745943.
# The geograpical coordinate of Don Valley Village are 43.78558000000004, -79.34985999999998.
# The geograpical coordinate of Dorset Park are 43.75533000000007, -79.27745999999996.
# The geograpical coordinate of Dovercourt-Wallace Emerson-Junction are 43.666040000000066, -79.43686999999994.
# The geograpical coordinate of Downsview-Roding-CFB are 43.72892000000007, -79.49135999999999.
# The geograpical coordinate of Dufferin Grove are 43.655140000000074, -79.43730999999997.
# The geograpical coordinate of East End-Danforth are 43.68420000000003, -79.29886999999997.
# The geograpical coordinate of Edenbridge-Humber Valley are 43.66991000000007, -79.52125999999998.
# The geograpical coordinate of Eglinton East are 43.73968000000008, -79.24553999999995.
# The geograpical coordinate of Elms-Old Rexdale are 43.72429000000005, -79.54955999999999.
# The geograpical coordinate of Englemount-Lawrence are 43.72192000000007, -79.43811999999997.
# The geograpical coordinate of Eringate-Centennial-West Deane are 43.661910000000034, -79.57737999999995.
# The geograpical coordinate of Etobicoke West Mall are 43.64450000000005, -79.56750999999997.
# The geograpical coordinate of Flemingdon Park are 43.71631000000008, -79.33170999999999.
# The geograpical coordinate of Forest Hill North are 43.705220000000054, -79.42744999999996.
# The geograpical coordinate of Forest Hill South are 43.69431000000003, -79.41609999999997.
# The geograpical coordinate of Glenfield-Jane Heights are 43.746770000000026, -79.51503999999994.
# The geograpical coordinate of Greenwood-Coxwell are 43.67195000000004, -79.32342999999997.
# The geograpical coordinate of Guildwood are 43.74953000000005, -79.18991999999997.
# The geograpical coordinate of Henry Farm are 43.772290000000055, -79.34085999999996.
# The geograpical coordinate of High Park North are 43.65769000000006, -79.46448999999996.
# The geograpical coordinate of High Park-Swansea are 43.64704000000006, -79.47113999999993.
# The geograpical coordinate of Highland Creek are 43.789480000000026, -79.17613999999998.
# The geograpical coordinate of Hillcrest Village are 43.803030000000035, -79.35345999999998.
# The geograpical coordinate of Humber Heights-Westmount are 43.69402000000008, -79.52125999999998.
# The geograpical coordinate of Humber Summit are 43.76016000000004, -79.55848999999995.
# The geograpical coordinate of Humbermede are 43.74284000000006, -79.53745999999995.
# The geograpical coordinate of Humewood-Cedarvale are 43.68942000000004, -79.42697999999996.
# The geograpical coordinate of Ionview are 43.736290000000054, -79.27319999999997.
# The geograpical coordinate of Islington-City Centre West are 43.63608000000005, -79.54295999999994.
# The geograpical coordinate of Junction Area are 43.66907000000003, -79.47202999999996.
# The geograpical coordinate of Keelesdale-Eglinton West are 43.68569000000008, -79.46927999999997.
# The geograpical coordinate of Kennedy Park are 43.72587000000004, -79.26228999999995.
# The geograpical coordinate of Kensington-Chinatown are 43.65331000000003, -79.39633999999995.
# The geograpical coordinate of Kingsview Village-The Westway are 43.69944000000004, -79.54923999999994.
# The geograpical coordinate of Kingsway South are 43.65433000000007, -79.51111999999995.
# The geograpical coordinate of L'Amoreaux are 43.797300000000064, -79.31221999999997.
# The geograpical coordinate of Lambton Baby Point are 43.65932000000004, -79.49750999999998.
# The geograpical coordinate of Lansing-Westgate are 43.75463000000008, -79.42419999999998.
# The geograpical coordinate of Lawrence Park North are 43.72830000000005, -79.40641999999997.
# The geograpical coordinate of Lawrence Park South are 43.71852000000007, -79.40575999999999.
# The geograpical coordinate of Leaside-Bennington are 43.70071000000007, -79.36757999999998.
# The geograpical coordinate of Little Portugal are 43.64755000000008, -79.42904999999996.
# The geograpical coordinate of Long Branch are 43.593540000000075, -79.53274999999996.
# The geograpical coordinate of Malvern are 43.81023000000005, -79.22037999999998.
# The geograpical coordinate of Maple Leaf are 43.714620000000025, -79.47977999999995.
# The geograpical coordinate of Markland Wood are 43.63391000000007, -79.56947999999994.
# The geograpical coordinate of Milliken are 43.82325000000003, -79.27728999999994.
# The geograpical coordinate of Mimico are 43.617290000000025, -79.49884999999995.
# The geograpical coordinate of Morningside are 43.78255000000007, -79.20522999999997.
# The geograpical coordinate of Moss Park are 43.65521000000007, -79.36816999999996.
# The geograpical coordinate of Mount Dennis are 43.68910000000005, -79.49551999999994.
# The geograpical coordinate of Mount Olive-Silverstone-Jamestown are 43.74721000000005, -79.58825999999993.
# The geograpical coordinate of Mount Pleasant East are 43.70563000000004, -79.38192999999995.
# The geograpical coordinate of Mount Pleasant West are 43.70541000000003, -79.39255999999995.
# The geograpical coordinate of New Toronto are 43.60143000000005, -79.50924999999995.
# The geograpical coordinate of Newtonbrook East are 43.793040000000076, -79.40694999999994.
# The geograpical coordinate of Newtonbrook West are 43.78818000000007, -79.43172999999996.
# The geograpical coordinate of Niagara are 43.64285000000007, -79.40789999999998.
# The geograpical coordinate of North Riverdale are 43.67158000000006, -79.35137999999995.
# The geograpical coordinate of North St. James Town are 43.670390000000054, -79.37608999999998.
# The geograpical coordinate of O'Connor-Parkview are 43.70872000000003, -79.30676999999997.
# The geograpical coordinate of Oakridge are 43.698830000000044, -79.27911999999998.
# The geograpical coordinate of Oakwood Village are 43.68888000000004, -79.43987999999996.
# The geograpical coordinate of Old East York are 43.69622000000004, -79.33288999999996.
# The geograpical coordinate of Palmerston-Little Italy are 43.659560000000056, -79.41921999999994.
# The geograpical coordinate of Parkwoods-Donalda are 43.75613000000004, -79.32879999999994.
# The geograpical coordinate of Pelmo Park-Humberlea are 43.71035000000006, -79.52926999999994.
# The geograpical coordinate of Playter Estates-Danforth are 43.680150000000026, -79.35524999999996.
# The geograpical coordinate of Pleasant View are 43.78812000000005, -79.33452999999997.
# The geograpical coordinate of Princess-Rosethorn are 43.665310000000034, -79.54560999999995.
# The geograpical coordinate of Regent Park are 43.660690000000045, -79.36030999999997.
# The geograpical coordinate of Rexdale-Kipling are 43.724330000000066, -79.56719999999996.
# The geograpical coordinate of Rockcliffe-Smythe are 43.67525000000006, -79.48863999999998.
# The geograpical coordinate of Roncesvalles are 43.64427000000006, -79.44268999999997.
# The geograpical coordinate of Rosedale-Moore Park are 43.681940000000054, -79.37938999999994.
# The geograpical coordinate of Rouge are 43.807660000000055, -79.17404999999997.
# The geograpical coordinate of Runnymede-Bloor West Village are 43.66246000000007, -79.48668999999995.
# The geograpical coordinate of Rustic are 43.71249000000006, -79.49722999999994.
# The geograpical coordinate of Scarborough Village are 43.738650000000064, -79.21698999999995.
# The geograpical coordinate of South Riverdale are 43.652750000000026, -79.33863999999994.
# The geograpical coordinate of South Parkdale are 43.63788000000005, -79.43255999999997.
# The geograpical coordinate of St. Andrew-Windfields are 43.75720000000007, -79.38187999999997.
# The geograpical coordinate of Steeles are 43.812310000000025, -79.32153999999997.
# The geograpical coordinate of Stonegate-Queensway are 43.63718000000006, -79.50057999999996.
# The geograpical coordinate of Tam O'Shanter-Sullivan are 43.78203000000008, -79.30539999999996.
# The geograpical coordinate of The Beaches are 43.67413000000005, -79.29643999999996.
# The geograpical coordinate of Thistletown-Beaumond Heights are 43.73858000000007, -79.56427999999994.
# The geograpical coordinate of Thorncliffe Park are 43.70732000000004, -79.34352999999999.
# The geograpical coordinate of Trinity-Bellwoods are 43.65043000000003, -79.41523999999998.
# The geograpical coordinate of University are 43.663760000000025, -79.40015999999997.
# The geograpical coordinate of Victoria Village are 43.73154000000005, -79.31427999999994.
# The geograpical coordinate of Waterfront Communities-The Island are 43.64296000000007, -79.37160999999998.
# The geograpical coordinate of West Hill are 43.76343000000003, -79.17819999999995.
# The geograpical coordinate of West Humber-Clairville are 43.71456000000006, -79.59260999999998.
# The geograpical coordinate of Westminster-Branson are 43.78206000000006, -79.44935999999996.
# The geograpical coordinate of Weston are 43.70440000000008, -79.50933999999995.
# The geograpical coordinate of Weston-Pellam Park are 43.67396000000008, -79.46136999999999.
# The geograpical coordinate of Wexford-Maryvale are 43.74860000000007, -79.29801999999995.
# The geograpical coordinate of Willowdale East are 43.77249000000006, -79.40040999999997.
# The geograpical coordinate of Willowdale West are 43.771340000000066, -79.42801999999995.
# The geograpical coordinate of Willowridge-Martingrove-Richview are 43.68514000000005, -79.54132999999996.
# The geograpical coordinate of Woburn are 43.767480000000035, -79.22828999999996.
# The geograpical coordinate of Woodbine Corridor are 43.67787000000004, -79.31488999999993.
# The geograpical coordinate of Woodbine-Lumsden are 43.69444000000004, -79.31058999999993.
# The geograpical coordinate of Wychwood are 43.67734000000007, -79.42496999999997.
# The geograpical coordinate of Yonge and Eglinton are 43.706750061226415, -79.3983099048018.
# The geograpical coordinate of Yonge-St.Clair are 43.68883000000005, -79.39886999999999.
# The geograpical coordinate of York University Heights are 43.75997000000007, -79.48519999999996.
# The geograpical coordinate of Yorkdale-Glen Park are 43.713880000000074, -79.45468999999997.
#                    Neighborhood              Borough  TotalCrimes  Longitude  \
# 0               Agincourt North          Scarborough          363  -79.26707
# 1  Agincourt South-Malvern West          Scarborough          478  -79.26935
# 2                     Alderwood            Etobicoke          204  -79.54116
# 3                         Annex  Old City of Toronto          943  -79.40280
# 4             Banbury-Don Mills           North York          403  -79.34852
#
#    Latitude
# 0  43.80930
# 1  43.78736
# 2  43.60496
# 3  43.66936
# 4  43.74041

# %% [markdown]
# #### Creating the map of Toronto with the neighborhoods

# %%
# Map of Toronto with the neighborhoods superimposed on it
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, crimes in zip(dfToronto['Latitude'], dfToronto['Longitude'], dfToronto['Borough'], dfToronto['Neighborhood'], dfToronto['TotalCrimes']):
    label = '{}, {}, {}'.format(neighborhood, borough, crimes)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='mediumorchid',
        fill=True,
        fill_color='#66CDAA',
        fill_opacity=0.6,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_7f17bdf836584a3a92ffcb501138952a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f17bdf836584a3a92ffcb501138952a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f17bdf836584a3a92ffcb501138952a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_7f17bdf836584a3a92ffcb501138952a%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B%5B43.809300000000064%2C%2043.787360000000035%2C%2043.60496000000006%2C%2043.66936000000004%2C%2043.740410000000054%2C%2043.763780000000054%2C%2043.657710000000066%2C%2043.777100000000075%2C%2043.794850000000054%2C%2043.73066000000006%2C%2043.69311000000005%2C%2043.75963000000007%2C%2043.694720000000075%2C%204 ...

# %%
borough_count=dfToronto['Borough'].value_counts()
borough_count
print("Number of boroughs in Toronto:", len(borough_count))
print("Neighborhood count for each borough:", borough_count)
# Out:
# Number of boroughs in Toronto: 6
# Neighborhood count for each borough: Old City of Toronto    43
# North York             33
# Scarborough            25
# Etobicoke              20
# York                   10
# East York               7
# Name: Borough, dtype: int64

# %% [markdown]
# ### London

# %%
# Merging the crime dataframe with the neighborhoods dataframe
dfLondon=pd.merge(London, crimeL, how='outer', on='Neighborhood')
dfLondon.sort_values('Neighborhood')

# Deleting the neighborhoods that were duplicates and merging the information from the borough columns
dfLondon=dfLondon.loc[dfLondon.index.drop([5, 25, 34, 37, 38, 40, 41, 47, 50, 53, 55, 55, 59, 65, 68, 69, 70, 71, 73,  77, 79, 82, 84, 87, 92, 94, 95, 96, 100, 102, 105, 115, 116, 136, 144, 145, 151, 154, 158, 164, 171, 173, 174, 175, 179, 186, 187, 197, 198, 199, 200, 203, 211, 212, 213, 228, 233, 234, 239, 241, 243, 244, 246, 255, 271, 273, 278, 284, 287, 289, 308, 312, 321, 323, 332, 340, 347, 351, 353, 360, 365, 367, 374, 375, 386, 387, 394, 395, 403, 408, 410, 434, 447, 453, 457, 459, 461, 469, 471, 472, 480, 482, 490, 493, 495, 497, 503, 520, 526, 527, 531, 534, 536, 595, 639, 644, 687, 707, 709, 739, 744, 766, 810, 830, 931])]
dfLondon['Borough_x']=dfLondon['Borough_x'].mask(pd.isnull, dfLondon['Borough_y'])
dfLondon=dfLondon.drop(['Borough_y'], axis=1)
dfLondon.columns=['Neighborhood', 'Borough', 'TotalCrimes']
dfLondon['TotalCrimes']=dfLondon['TotalCrimes'].fillna(0)

# The geocoder does not work if the borough is 'City'
dfLondon=dfLondon[dfLondon.Borough != 'City']

dfLondon['Borough']=dfLondon['Borough'].replace({'Lambeth, Southwark':'Lambeth', 'Barnet, Brent, Camden':'Camden', 'Camden, Islington':'Camden',
                                     'Brent, Camden':'Camden', 'Haringey, Islington':'Islington', 'City, Westminster':'Westminster', 'Greenwich, Lewisham':'Greenwich',
                                     'Bexley, Greenwich':'Greenwich','Islington, City':'Islington', 'Lewisham, Southwark':'Lewisham', 'Islington, Camden':'Islington'})

# Selecting only the boroughs that are in the metropolitan area of London
dfLondon=dfLondon[dfLondon['Borough'].isin(['Camden', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Islington', 'Kensington and Chelsea', 'Lambeth', 'Lewisham', 'Southwark', 'Tower Hamlets', 'Wandsworth', 'Westminster'])]
dfLondon['Neighborhood']=dfLondon['Neighborhood'].replace({'Town':'Town, Askew and Munster', 'Evelyn':'Evelyn and Lewisham Central', 'Dalgarno':'Kensington and Chelsea', 'Tooting':'Wandsworth', 'Chinatown':'Westminster'})
dfLondon=dfLondon.sort_values('Neighborhood').reset_index()
dfLondon.drop(dfLondon.iloc[:, 0:1], axis=1, inplace=True)  

# Based on the coordinates resulted from the geocoder, the neighborhoods with the index values below
#have the same coordinates so I have removed them for the analysis to be more accurate
dfLondon=dfLondon.loc[dfLondon.index.drop([1, 6, 13, 34, 39, 49, 62, 64, 85, 92, 99, 102, 117, 131, 133, 145, 149, 151, 153, 157, 163, 166, 170, 176, 178, 179, 189, 197, 203, 214, 217, 218, 229, 236, 243, 247, 255, 259, 263, 265, 275, 280, 284, 288, 289, 298])]
dfLondon=dfLondon.sort_values('Neighborhood').reset_index()
dfLondon.drop(dfLondon.iloc[:, 0:1], axis=1, inplace=True)

# In order not to lose any crime data by deleting the neighborhoods with the same coordinates,
#the below neighborhoods were updated with the sum of the crimes in the deleted ones
indexlist=[75, 118, 121, 230, 239, 252]
valuelist=[1526, 17296, 23374, 5767, 18435, 32207]
        
for i in indexlist:
        dfLondon.loc[i, 'TotalCrimes']=999999

result=dfLondon.where(dfLondon['TotalCrimes']==999999)
result=result.dropna(axis=0)  
result['TotalCrimes']=valuelist

dfLondon.drop(dfLondon[dfLondon.TotalCrimes == 999999].index, inplace=True)
dfLondon=pd.concat([dfLondon, result]) 

print("Shape of the final dfLondon:", dfLondon.shape)
dfLondon.head()
# Out:
# Shape of the final dfLondon: (260, 3)
#   Neighborhood                 Borough  TotalCrimes
# 0   Abbey Road             Westminster       1215.0
# 1      Addison  Hammersmith and Fulham       2634.0
# 2      Aldwych             Westminster          0.0
# 3        Angel               Islington          0.0
# 4      Archway               Islington          0.0

# %%
neighborhood = dfLondon['Neighborhood']
borough=dfLondon['Borough']

# Empty lists that will store the coordinates information from the geocoder
latitude = []
longitude = []
n = 0

# Loop that keeps on trying to get the latitude and longitude for each neighborhood until it succeedes
while n < len(neighborhood):
    g = geocoder.arcgis('{}, {}, London, England'.format(neighborhood[n], borough[n]))
    lat_lng_coords = g.latlng
    print('The geograpical coordinate of {}, {} are {}, {}.'.format(neighborhood[n], borough[n], lat_lng_coords[0], lat_lng_coords[1]))
    latitude.append(lat_lng_coords[0])
    longitude.append(lat_lng_coords[1])
    n = n + 1

dfLondon['Longitude'] = longitude
dfLondon['Latitude'] = latitude
dfLondon.head()
# Out:
# The geograpical coordinate of Abbey Road, Westminster are 51.49765730513152, -0.12719693873343343.
# The geograpical coordinate of Addison, Hammersmith and Fulham are 51.48260000000005, -0.21287999999992735.
# The geograpical coordinate of Aldwych, Westminster are 51.51265251684556, -0.11860743006660546.
# The geograpical coordinate of Angel, Islington are 51.532020000000045, -0.10625999999996338.
# The geograpical coordinate of Archway, Islington are 51.56574780726418, -0.13492240619480866.
# The geograpical coordinate of Avonmore and Brook Green, Hammersmith and Fulham are 51.49620224997504, -0.2191129500854935.
# The geograpical coordinate of Balham, Wandsworth are 51.44421949800005, -0.1505454249999616.
# The geograpical coordinate of Bankside, Southwark are 51.50816355244705, -0.09521630696980721.
# The geograpical coordinate of Barnsbury, Islington are 51.536488687022775, -0.11090694947026249.
# The geograpical coordinate of Battersea, Wandsworth are 51.459230038551254, -0.1730798884169502.
# The geograpical coordinate of Bayswater, Westminster are 51.51229302300004, -0.18327252499994984.
# The geograpical coordinate of Belgravia, Westminster are 51.494858453208806, -0.1274498762172157.
# The geograpical coordinate of Bellingham, Lewisham are 51.42737789200004, -0.02502469699993526.
# The geograpical coordinate of Belsize, Camden are 51.54931000000005, -0.17141999999995505.
# The geograpical coordinate of Bermondsey, Southwark are 51.49499622600007, -0.076444745999936.
# The geograpical coordinate of Bethnal Green, Tower Hamlets are 51.52747203400003, -0.05592983099995763.
# The geograpical coordinate of Bishop's, Lambeth are 51.49334968866645, -0.10999237348446207.
# The geograpical coordinate of Blackheath, Lewisham are 51.47296385213711, -0.014942784978495686.
# The geograpical coordinate of Blackheath Westcombe, Greenwich are 51.472505753991044, -0.010822825429541225.
# The geograpical coordinate of Blackwall, Tower Hamlets are 51.50846765700004, -0.0011996829999247893.
# The geograpical coordinate of Blackwall & Cubitt Town, Tower Hamlets are 51.49531522900003, -0.014150935999964531.
# The geograpical coordinate of Bloomsbury, Camden are 51.52086720800003, -0.12693026499994176.
# The geograpical coordinate of Bow East, Tower Hamlets are 51.499799979617734, -0.01749998890679194.
# The geograpical coordinate of Bow West, Tower Hamlets are 51.50957003073282, -0.05649490750232644.
# The geograpical coordinate of Brixton Hill, Lambeth are 51.454935015418634, -0.11953585164379911.
# The geograpical coordinate of Brockley, Lewisham are 51.45562162300007, -0.03663136799997346.
# The geograpical coordinate of Bromley North, Tower Hamlets are 51.51493508528379, -0.04281488492247378.
# The geograpical coordinate of Bromley South, Tower Hamlets are 51.51493508528379, -0.04281488492247378.
# The geograpical coordinate of Brompton & Hans Town, Kensington and Chelsea are 51.50010005175142, -0.16290991574661007.
# The geograpical coordinate of Brownswood, Hackney are 51.56399000000005, -0.09276999999997315.
# The geograpical coordinate of Bryanston and Dorset Square, Westminster are 51.52266976108265, -0.16164476143109655.
# The geograpical coordinate of Caledonian, Islington are 51.539270000000045, -0.11672999999996136.
# The geograpical coordinate of Camberwell Green, Southwark are 51.47547003881796, -0.0934899459096954.
# The geograpical coordinate of Cambridge Heath, Tower Hamlets are 51.522072933666855, -0.05547411602884231.
# The geograpical coordinate of Camden Town with Primrose Hill, Camden are 51.51287349128656, -0.10663203043213688.
# The geograpical coordinate of Canary Wharf, Tower Hamlets are 51.50342524900003, -0.01777503899995736.
# The geograpical coordinate of Canonbury, Islington are 51.546197078000034, -0.09495302899995295.
# The geograpical coordinate of Cantelowes, Camden are 51.54617592404498, -0.13166051264481657.
# The geograpical coordinate of Catford South, Lewisham are 51.44456932700007, -0.020052426999939144.
# The geograpical coordinate of Cathedrals, Southwark are 51.50506000104596, -0.08848004047223412.
# The geograpical coordinate of Cazenove, Hackney are 51.56557767227896, -0.06697657541357833.
# The geograpical coordinate of Chalk Farm, Camden are 51.542843665290256, -0.14859191798621435.
# The geograpical coordinate of Charing Cross, Westminster are 51.507215332937875, -0.12752646648016996.
# The geograpical coordinate of Charlton, Greenwich are 51.47343178447259, 0.004821371156515389.
# The geograpical coordinate of Chelsea Riverside, Kensington and Chelsea are 51.49972504540334, -0.1604849054293993.
# The geograpical coordinate of Chinbrook, Lewisham are 51.43155003964509, 0.02224506811343474.
# The geograpical coordinate of Church Street, Westminster are 51.52142799429525, -0.17336614280723248.
# The geograpical coordinate of Churchill, Westminster are 51.50225000000006, -0.1290199999999686.
# The geograpical coordinate of Clapham Common, Lambeth are 51.461656031000075, -0.13802183999996487.
# The geograpical coordinate of Clapham Town, Lambeth are 51.46309966300004, -0.13436400799997728.
# The geograpical coordinate of Clerkenwell, Islington are 51.525651964000076, -0.10568618399997831.
# The geograpical coordinate of Clissold, Hackney are 51.59088059518965, -0.15589722156857194.
# The geograpical coordinate of Coldharbour, Lambeth are 51.502595206313444, -0.007697129429784564.
# The geograpical coordinate of Coldharbour and New Eltham, Greenwich are 51.429910057424536, 0.05750505256351346.
# The geograpical coordinate of College, Southwark are 51.50622000000004, -0.09027999999995018.
# The geograpical coordinate of College Park and Old Oak, Hammersmith and Fulham are 51.52309006150955, -0.2999698744621071.
# The geograpical coordinate of Courtfield, Kensington and Chelsea are 51.52265998605762, -0.20793003971127177.
# The geograpical coordinate of Cricklewood, Camden are 51.55836000000005, -0.21223999999995158.
# The geograpical coordinate of Crofton Park, Lewisham are 51.454801994000036, -0.03601881199995205.
# The geograpical coordinate of Cubitt Town, Tower Hamlets are 51.49531522900003, -0.014150935999964531.
# The geograpical coordinate of Dalston, Hackney are 51.54835168039425, -0.06486077664158618.
# The geograpical coordinate of De Beauvoir, Hackney are 51.53793001153409, -0.08978996430047914.
# The geograpical coordinate of Denmark Hill, Southwark are 51.47374021158635, -0.09315989340351101.
# The geograpical coordinate of Deptford, Lewisham are 51.477627719000054, -0.025951099999929284.
# The geograpical coordinate of Downham, Lewisham are 51.42593067900003, 0.0019852310000487705.
# The geograpical coordinate of Dulwich, Southwark are 51.43538032600003, -0.08014421099994706.
# The geograpical coordinate of Earl's Court, Kensington and Chelsea are 51.49291899700006, -0.19584158399993612.
# The geograpical coordinate of Earlsfield, Wandsworth are 51.442360000000065, -0.18811999999996942.
# The geograpical coordinate of East Dulwich, Southwark are 51.451524379000034, -0.07149354299997412.
# The geograpical coordinate of East Putney, Wandsworth are 51.448840000000075, -0.19301999999993313.
# The geograpical coordinate of East Walworth, Southwark are 51.489290295000046, -0.08660985699992807.
# The geograpical coordinate of Elephant and Castle, Southwark are 51.49491400833548, -0.10017453313619537.
# The geograpical coordinate of Eltham North, Greenwich are 51.502140039346244, 0.00854011159788115.
# The geograpical coordinate of Eltham South, Greenwich are 51.45074721700007, 0.057273558000019875.
# The geograpical coordinate of Eltham West, Greenwich are 51.473389949703005, -0.006576108881332623.
# The geograpical coordinate of Evelyn and Lewisham Central, Lewisham are 51.457096541000055, -0.013680711999938922.
# The geograpical coordinate of Fairfield, Wandsworth are 51.45782139043356, -0.19005234951801442.
# The geograpical coordinate of Farringdon, Islington are 51.52107973200003, -0.10544355899997981.
# The geograpical coordinate of Ferndale, Lambeth are 51.57961274685613, -0.07029392518728969.
# The geograpical coordinate of Finsbury Park, Islington are 51.56452486400008, -0.10888995499993825.
# The geograpical coordinate of Fitzrovia, Camden are 51.521417573000065, -0.13777646399995547.
# The geograpical coordinate of Forest Hill, Lewisham are 51.43955766900007, -0.052097707999962495.
# The geograpical coordinate of Fortune Green, Camden are 51.5538698425502, -0.19592783235350686.
# The geograpical coordinate of Frognal and Fitzjohns, Camden are 51.54953602191567, -0.18140596194924172.
# The geograpical coordinate of Fulham Broadway, Hammersmith and Fulham are 51.48016833447161, -0.1964039264323193.
# The geograpical coordinate of Fulham Reach, Hammersmith and Fulham are 51.471626222000054, -0.2112245479999615.
# The geograpical coordinate of Furzedown, Wandsworth are 51.42095528200008, -0.15285098799995467.
# The geograpical coordinate of Gipsy Hill, Lambeth are 51.42400788547244, -0.0835580168276811.
# The geograpical coordinate of Glyndon, Greenwich are 51.48783296254662, 0.0818330014787606.
# The geograpical coordinate of Gospel Oak, Camden are 51.55403594300003, -0.15440335899995716.
# The geograpical coordinate of Grange, Southwark are 51.50573373789071, -0.10000176546602337.
# The geograpical coordinate of Greenwich West, Greenwich are 51.48160370791553, -0.009205912140149387.
# The geograpical coordinate of Grove Park, Lewisham are 51.46697816432267, -0.020433656518533114.
# The geograpical coordinate of Hackney Central, Hackney are 51.54713000000004, -0.055099999999924876.
# The geograpical coordinate of Hackney Downs, Hackney are 51.54821000000004, -0.06007999999997082.
# The geograpical coordinate of Hackney Marshes, Hackney are 51.55195000000003, -0.025009999999952015.
# The geograpical coordinate of Hackney Wick, Hackney are 51.54560819752571, -0.033779698333416694.
# The geograpical coordinate of Haggerston, Hackney are 51.53849000000008, -0.07554999999996426.
# The geograpical coordinate of Hammersmith Broadway, Hammersmith and Fulham are 51.49297113989598, -0.22447817577620854.
# The geograpical coordinate of Hampstead Town, Camden are 51.53164031343497, -0.13902860264854483.
# The geograpical coordinate of Harrow Road, Westminster are 51.530630302865276, -0.22902896241806103.
# The geograpical coordinate of Haverstock, Camden are 51.54396005745231, -0.1528948825564811.
# The geograpical coordinate of Herne Hill, Lambeth are 51.45616286557018, -0.09761423286890289.
# The geograpical coordinate of Highbury East, Islington are 51.54586668298202, -0.103194040406455.
# The geograpical coordinate of Highgate, Camden are 51.566450044776516, -0.13649992185482063.
# The geograpical coordinate of Hither Green, Lewisham are 51.45083000000005, -0.0006299999999441752.
# The geograpical coordinate of Holborn and Covent Garden, Camden are 51.511625042889094, -0.12248491874079548.
# The geograpical coordinate of Holland, Kensington and Chelsea are 51.52265998605762, -0.20793003971127177.
# The geograpical coordinate of Holland Park, Kensington and Chelsea are 51.501642018379094, -0.2055210625559087.
# The geograpical coordinate of Holloway, Islington are 51.53371000000004, -0.10727999999994609.
# The geograpical coordinate of Homerton, Hackney are 51.54690000000005, -0.042339999999967404.
# The geograpical coordinate of Honor Oak, Lewisham are 51.44884360200007, -0.05295467299993106.
# The geograpical coordinate of Horn Park, Greenwich are 51.4883252501815, 0.017883532221078524.
# The geograpical coordinate of Hoxton, Hackney are 51.544888045193176, -0.059544631392240546.
# The geograpical coordinate of Hoxton East & Shoreditch, Hackney are 51.53942504969399, -0.07100993305026293.
# The geograpical coordinate of Hoxton West, Hackney are 51.54818000000006, -0.07326999999997952.
# The geograpical coordinate of Hyde Park, Westminster are 51.492238984657355, -0.13355832756683048.
# The geograpical coordinate of Island Gardens, Tower Hamlets are 51.48682003677209, -0.00959991943538796.
# The geograpical coordinate of Islington, Islington are 51.534380000000056, -0.1089399999999614.
# The geograpical coordinate of Kennington, Lambeth are 51.49805963608244, -0.11211326340809348.
# The geograpical coordinate of Kensington, Kensington and Chelsea are 51.500575894000065, -0.19435759199996028.
# The geograpical coordinate of Kensington and Chelsea, Kensington and Chelsea are 51.52290313700007, -0.2083361439999294.
# The geograpical coordinate of Kentish Town, Camden are 51.55078000000003, -0.14064999999993688.
# The geograpical coordinate of Kidbrooke with Hornfair, Greenwich are 51.46491707300004, 0.03321920500002307.
# The geograpical coordinate of Kilburn, Camden are 51.54520000000008, -0.2018799999999601.
# The geograpical coordinate of King's Cross, Camden are 51.53200000000004, -0.12350999999995338.
# The geograpical coordinate of King's Park, Hackney are 51.53903879623543, -0.062329960493379966.
# The geograpical coordinate of Knight's Hill, Lambeth are 51.49064005686822, -0.10635991987354984.
# The geograpical coordinate of Knightsbridge and Belgravia, Westminster are 51.50186708308644, -0.16032901665684737.
# The geograpical coordinate of Ladywell, Lewisham are 51.45641000000006, -0.01949999999993679.
# The geograpical coordinate of Lancaster Gate, Westminster are 51.51144536862955, -0.17986242483595888.
# The geograpical coordinate of Lansbury, Tower Hamlets are 51.49999000000008, -0.01044999999993479.
# The geograpical coordinate of Larkhall, Lambeth are 51.46802003563755, -0.13945487800029355.
# The geograpical coordinate of Lea Bridge, Hackney are 51.551018824015664, -0.022262363740818032.
# The geograpical coordinate of Lee Green, Lewisham are 51.46257904172623, -0.009845788263285263.
# The geograpical coordinate of Limehouse, Tower Hamlets are 51.51422149600006, -0.034082523999927616.
# The geograpical coordinate of Lisson Grove, Westminster are 51.52603000000005, -0.17173999999994294.
# The geograpical coordinate of Little Venice, Westminster are 51.497475049224434, -0.1290448895325227.
# The geograpical coordinate of London Fields, Hackney are 51.53783000000004, -0.06084999999995944.
# The geograpical coordinate of Lower Clapton, Hackney are 51.55320502523465, -0.05318856050233755.
# The geograpical coordinate of Maida Vale, Westminster are 51.52482534586942, -0.1769193031850699.
# The geograpical coordinate of Manor House, Hackney are 51.556959991137006, -0.06161000582463316.
# The geograpical coordinate of Marylebone High Street, Westminster are 51.52049985763112, -0.15184381710562092.
# The geograpical coordinate of Maze Hill, Greenwich are 51.48170504322354, 0.002405103297164146.
# The geograpical coordinate of Middle Park and Sutcliffe, Greenwich are 51.48361888097917, 0.005211169713027966.
# The geograpical coordinate of Mile End, Tower Hamlets are 51.520401205576995, -0.05340667512217314.
# The geograpical coordinate of Millbank, Westminster are 51.49565014088079, -0.1253142169688638.
# The geograpical coordinate of Millwall, Tower Hamlets are 51.49108149400007, -0.020644565999930364.
# The geograpical coordinate of New Cross, Lewisham are 51.47591253400003, -0.039489744999968934.
# The geograpical coordinate of New Eltham, Greenwich are 51.43817446200006, 0.06293877000007342.
# The geograpical coordinate of Newington, Southwark are 51.48822158200005, -0.09941694599996254.
# The geograpical coordinate of Nightingale, Wandsworth are 51.44681503597964, -0.1649949141614968.
# The geograpical coordinate of Nine Elms, Wandsworth are 51.47770494800005, -0.14464135799994438.
# The geograpical coordinate of North Kensington, Kensington and Chelsea are 51.51841078800004, -0.21626713399996333.
# The geograpical coordinate of Nunhead, Southwark are 51.45875067900005, -0.056016710999927.
# The geograpical coordinate of Old Ford, Tower Hamlets are 51.5166053416564, -0.05654560848704024.
# The geograpical coordinate of Old Oak Common, Hammersmith and Fulham are 51.52133061500007, -0.24952309699995112.
# The geograpical coordinate of Oval, Lambeth are 51.49447082077311, -0.12006581821638082.
# The geograpical coordinate of Paddington, Westminster are 51.493000055892864, 0.04085008522535816.
# The geograpical coordinate of Palace Riverside, Hammersmith and Fulham are 51.46224138942707, -0.19794076632798122.
# The geograpical coordinate of Parsons Green and Walham, Hammersmith and Fulham are 51.47417598723108, -0.20032901838868822.
# The geograpical coordinate of Peckham, Southwark are 51.47513384900003, -0.06841001299994787.
# The geograpical coordinate of Peckham Rye, Southwark are 51.46121055183938, -0.06224431936962211.
# The geograpical coordinate of Peninsula, Greenwich are 51.50081978558253, 0.005093140019858538.
# The geograpical coordinate of Pentonville, Islington are 51.53138256091254, -0.11432108844104645.
# The geograpical coordinate of Perry Vale, Lewisham are 51.43621910132551, -0.05032876161392548.
# The geograpical coordinate of Pimlico, Westminster are 51.49175000000008, -0.13999999999992951.
# The geograpical coordinate of Plumstead, Greenwich are 51.481283114000064, 0.07636291200003598.
# The geograpical coordinate of Poplar, Tower Hamlets are 51.51097530200008, -0.01753355599993256.
# The geograpical coordinate of Primrose Hill, Camden are 51.54083687692025, -0.15706515957439343.
# The geograpical coordinate of Putney, Wandsworth are 51.460762385000066, -0.21709079199996495.
# The geograpical coordinate of Queen's Gate, Kensington and Chelsea are 51.4979405268669, -0.17963061771252387.
# The geograpical coordinate of Queenstown, Wandsworth are 51.46147000000008, -0.18724999999994907.
# The geograpical coordinate of Ratcliff, Tower Hamlets are 51.510716592294315, -0.04333154023440108.
# The geograpical coordinate of Ravenscourt Park, Hammersmith and Fulham are 51.4952464741834, -0.2398320623606706.
# The geograpical coordinate of Regent's Park, Camden are 51.538421554433015, -0.14675747045636728.
# The geograpical coordinate of Regent's Park, Westminster are 51.497870000000034, -0.12627999999995154.
# The geograpical coordinate of Riverside, Southwark are 51.50689567754993, -0.0542085287289207.
# The geograpical coordinate of Roehampton and Putney Heath, Wandsworth are 51.451150030573444, -0.23678993817270566.
# The geograpical coordinate of Rotherhithe, Southwark are 51.49802642600008, -0.04597466799992844.
# The geograpical coordinate of Royal Hospital, Kensington and Chelsea are 51.483770050799365, -0.16360988848080638.
# The geograpical coordinate of Rushey Green, Lewisham are 51.44730213671518, -0.018446067310632967.
# The geograpical coordinate of Sands End, Hammersmith and Fulham are 51.47204291500003, -0.1844976359999464.
# The geograpical coordinate of Shacklewell, Hackney are 51.552399750993644, -0.07096606996100938.
# The geograpical coordinate of Shadwell, Tower Hamlets are 51.51111000000003, -0.05674999999996544.
# The geograpical coordinate of Shepherd's Bush Green, Hammersmith and Fulham are 51.49599667615053, -0.22394995215532276.
# The geograpical coordinate of Shooters Hill, Greenwich are 51.47275480140007, 0.008272470056086828.
# The geograpical coordinate of Somerstown, Camden are 51.535886174325135, -0.1275253812030762.
# The geograpical coordinate of South Bermondsey, Southwark are 51.48755928800006, -0.05411440199992512.
# The geograpical coordinate of South Camberwell, Southwark are 51.47627808800007, -0.0938073859999804.
# The geograpical coordinate of South Hackney, Hackney are 51.540060166000046, -0.046639771999934965.
# The geograpical coordinate of South Kensington, Kensington and Chelsea are 51.492758439000056, -0.18137017199995853.
# The geograpical coordinate of Southend, Lewisham are 51.42935602700004, -0.011172092999970573.
# The geograpical coordinate of Southfields, Wandsworth are 51.45432511378201, -0.1998066946203543.
# The geograpical coordinate of Spitalfields & Banglatown, Tower Hamlets are 51.518380000000036, -0.0746799999999439.
# The geograpical coordinate of Springfield, Hackney are 51.568400731884914, -0.05813210506072001.
# The geograpical coordinate of St Giles, Camden are 51.51482003400008, -0.1249877109999602.
# The geograpical coordinate of St John's Wood, Westminster are 51.49571731911158, -0.1273601306042042.
# The geograpical coordinate of St Johns, Lewisham are 51.46989504642315, -0.01357989852017738.
# The geograpical coordinate of St Luke's, Islington are 51.525680513000054, -0.09634324899997182.
# The geograpical coordinate of St Pancras, Camden are 51.532350000000065, -0.12575999999995702.
# The geograpical coordinate of St. Dunstan's, Tower Hamlets are 51.517115042785704, -0.04069988152045312.
# The geograpical coordinate of St. George's, Islington are 52.25063603254099, 0.1254762820760194.
# The geograpical coordinate of St. James's, Westminster are 51.491190000000074, -0.13481999999993377.
# The geograpical coordinate of St. Katharine's & Wapping, Tower Hamlets are 51.50788458789803, -0.07106499641446222.
# The geograpical coordinate of St. Leonard's, Lambeth are 51.512659711583, -0.008880849191425214.
# The geograpical coordinate of St. Mary's, Islington are 51.53009000000003, -0.09895999999997684.
# The geograpical coordinate of St. Mary's Park, Wandsworth are 51.461490000000026, -0.20406999999994468.
# The geograpical coordinate of St. Pancras and Somers Town, Camden are 51.54281003938186, -0.13747989206456168.
# The geograpical coordinate of St. Peter's, Tower Hamlets are 51.49999000000008, -0.01044999999993479.
# The geograpical coordinate of Stamford Hill, Hackney are 51.548185118419724, -0.06545306296849776.
# The geograpical coordinate of Stamford Hill West, Hackney are 51.57046066400005, -0.07578630899996597.
# The geograpical coordinate of Stepney Green, Tower Hamlets are 51.517030000000034, -0.04622999999998001.
# The geograpical coordinate of Stockwell, Lambeth are 51.46417088700008, -0.12935346399996206.
# The geograpical coordinate of Stoke Newington, Hackney are 51.55255457989421, -0.07492175541721777.
# The geograpical coordinate of Streatham Hill, Lambeth are 51.43870002400007, -0.12801988099994333.
# The geograpical coordinate of Streatham South, Lambeth are 51.43205633200006, -0.1292696819999719.
# The geograpical coordinate of Streatham Wells, Lambeth are 51.43999456800003, -0.11621114999996962.
# The geograpical coordinate of Surrey Docks, Southwark are 51.502416325467365, -0.10268353805876189.
# The geograpical coordinate of Swiss Cottage, Camden are 51.54281699774736, -0.17420767315821428.
# The geograpical coordinate of Sydenham, Lewisham are 51.42755095700005, -0.054190615999971214.
# The geograpical coordinate of Sydenham Hill, Lewisham are 51.439202299030825, -0.06372728944780127.
# The geograpical coordinate of Telegraph Hill, Lewisham are 51.56178848300699, -0.19044840748652234.
# The geograpical coordinate of Temple, Westminster are 51.51368092621647, -0.11088535107831915.
# The geograpical coordinate of Thamesfield, Wandsworth are 51.588760009775285, -0.10832997975327885.
# The geograpical coordinate of Thamesmead Moorings, Greenwich are 51.504407868000044, 0.11885752700004559.
# The geograpical coordinate of Thornton, Lambeth are 51.49458259710082, -0.25253795011325947.
# The geograpical coordinate of Thurlow Park, Lambeth are 51.44097875076503, -0.08884790134346895.
# The geograpical coordinate of Tollington, Islington are 51.53796237061694, -0.11951534284528224.
# The geograpical coordinate of Tower Hill, Tower Hamlets are 51.50605116016567, -0.07499913929708292.
# The geograpical coordinate of Town, Askew and Munster, Hammersmith and Fulham are 51.47439003059378, -0.20687995488145816.
# The geograpical coordinate of Tufnell Park, Islington are 51.55756780000007, -0.13039933499993595.
# The geograpical coordinate of Tulse Hill, Lambeth are 51.439123461000065, -0.10290860799995016.
# The geograpical coordinate of Upper Clapton, Hackney are 51.565943247000064, -0.06195192599994925.
# The geograpical coordinate of Upper Holloway, Islington are 51.56779360000007, -0.13161047099993084.
# The geograpical coordinate of Vauxhall, Lambeth are 51.48559000000006, -0.12332999999995309.
# The geograpical coordinate of Victoria, Hackney are 51.54518000000007, -0.07021999999994932.
# The geograpical coordinate of Village, Southwark are 51.50534000000005, -0.09431999999992513.
# The geograpical coordinate of Vincent Square, Westminster are 51.49286529051331, -0.13385605925643115.
# The geograpical coordinate of Wandsworth, Wandsworth are 51.47040000000004, -0.13902999999993426.
# The geograpical coordinate of Wandsworth Common, Wandsworth are 51.44671000000005, -0.16512999999997646.
# The geograpical coordinate of Wapping, Tower Hamlets are 51.50458000000003, -0.05598999999995158.
# The geograpical coordinate of Weavers, Tower Hamlets are 51.52246640223904, -0.0669948813656186.
# The geograpical coordinate of Well Hall, Greenwich are 51.464095304281955, 0.051011148811603534.
# The geograpical coordinate of West Brompton, Kensington and Chelsea are 51.48728284800006, -0.18956789399993568.
# The geograpical coordinate of West Hampstead, Camden are 51.55199579500004, -0.1961148689999277.
# The geograpical coordinate of West Hill, Wandsworth are 51.455262420068614, -0.20730780080664818.
# The geograpical coordinate of West Kensington, Hammersmith and Fulham are 51.492061411000066, -0.20735662099997398.
# The geograpical coordinate of West Norwood, Lambeth are 51.42793861800004, -0.09861031699995237.
# The geograpical coordinate of West Putney, Wandsworth are 51.456660000000056, -0.20259999999996126.
# The geograpical coordinate of Westbourne, Westminster are 51.628248878120935, 0.01298627842834142.
# The geograpical coordinate of Westcombe Park, Greenwich are 51.48408000000006, 0.018630000000030122.
# The geograpical coordinate of Westminster, Westminster are 51.50089324133152, -0.12280028129198817.
# The geograpical coordinate of Whitechapel, Tower Hamlets are 51.51917000000003, -0.059659999999951197.
# The geograpical coordinate of Whitefoot, Lewisham are 51.465280000000064, -0.0132099999999582.
# The geograpical coordinate of Woodberry Down, Hackney are 51.57117007009121, -0.09260967755088641.
# The geograpical coordinate of Woolwich Common, Greenwich are 51.486073750680866, 0.013843779147213551.
# The geograpical coordinate of Woolwich Riverside, Greenwich are 51.48563000000007, 0.006170000000054188.
# The geograpical coordinate of Wormholt and White City, Hammersmith and Fulham are 51.51185165700008, -0.22433464699997785.
# The geograpical coordinate of Wormwood Scrubs, Hammersmith and Fulham are 51.516279206000036, -0.2340785949999713.
#   Neighborhood                 Borough  TotalCrimes  Longitude   Latitude
# 0   Abbey Road             Westminster       1215.0  -0.127197  51.497657
# 1      Addison  Hammersmith and Fulham       2634.0  -0.212880  51.482600
# 2      Aldwych             Westminster          0.0  -0.118607  51.512653
# 3        Angel               Islington          0.0  -0.106260  51.532020
# 4      Archway               Islington          0.0  -0.134922  51.565748

# %% [markdown]
# #### Creating the map of London with the neighborhoods

# %%
# Map of London with the neighborhoods superimposed on it
map_London = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood, crimes in zip(dfLondon['Latitude'], dfLondon['Longitude'], dfLondon['Borough'], dfLondon['Neighborhood'], dfLondon['TotalCrimes']):
    label = '{}, {}, {}'.format(neighborhood, borough, crimes)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='mediumorchid',
        fill=True,
        fill_color='#66CDAA',
        fill_opacity=0.6,
        parse_html=False).add_to(map_London)  
    
map_London
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_cee4d6136e5d43e0bf36dfdc46c6a1aa%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cee4d6136e5d43e0bf36dfdc46c6a1aa%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cee4d6136e5d43e0bf36dfdc46c6a1aa%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_cee4d6136e5d43e0bf36dfdc46c6a1aa%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B%5B51.49765730513152%2C%2051.48260000000005%2C%2051.51265251684556%2C%2051.532020000000045%2C%2051.56574780726418%2C%2051.49620224997504%2C%2051.44421949800005%2C%2051.50816355244705%2C%2051.536488687022775%2C%2051.459230038551254%2C%2051.51229302300004%2C%2051.494858453208806%2C%2051.42737789200004%2C%2051.54 ...

# %%
borough_count=dfLondon['Borough'].value_counts()
borough_count
print("Number of boroughs in metropolitan London:", len(borough_count))
print("Neighborhood count for each borough:", borough_count)
# Out:
# Number of boroughs in metropolitan London: 12
# Neighborhood count for each borough: Hackney                   28
# Tower Hamlets             28
# Westminster               26
# Camden                    25
# Lewisham                  24
# Lambeth                   22
# Southwark                 21
# Greenwich                 21
# Islington                 18
# Wandsworth                18
# Hammersmith and Fulham    16
# Kensington and Chelsea    13
# Name: Borough, dtype: int64

# %% [markdown]
# ## Setting up the Foursquare credentials

# %%
# Foursquare credentials
CLIENT_ID = 'T3THHYDPV3NSFOCGTSFMG2REPZK2L1FWNLZPUUTYHEIJDGIF' # your Foursquare ID
CLIENT_SECRET = 'UPBT2EZKN4L054EO2NR2I0RD5EHHZ1LMCOMXKF4WOUJCZHBW' # your Foursquare Secret
ACCESS_TOKEN = 'YZHHK4EQ4RNDT14K5ISYM4DBXSYJRO0C3HT0H0RDU2OVV1WA'
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: T3THHYDPV3NSFOCGTSFMG2REPZK2L1FWNLZPUUTYHEIJDGIF
# CLIENT_SECRET:UPBT2EZKN4L054EO2NR2I0RD5EHHZ1LMCOMXKF4WOUJCZHBW

# %%
# IDs from Foursquare for the places that the analysis of the neighborhoods is based
id_ArtsEntertainment='4d4b7104d754a06370d81259'
id_Colleges='4d4b7105d754a06372d81259'
id_Restaurants='4d4b7105d754a06374d81259'
id_NightLife='4d4b7105d754a06376d81259'
id_OutdoorsRecreation='4d4b7105d754a06377d81259'
id_GovernmentBuilding='4bf58dd8d48988d126941735'
id_MedicalCenter='4bf58dd8d48988d104941735'
id_SpiritualCenter='4bf58dd8d48988d131941735'
id_FoodShop='4bf58dd8d48988d1f9941735'

# %%
# Function for retrieving the venues of each neighborhood, based on the coordinates of the 
#neighborhood and category ID of the venues, on a radius of 500m
def getNearbyVenues(names, latitudes, longitudes, categoryID, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        #API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng,
            categoryID,
            radius, 
            LIMIT)
            
        #GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        #Appending to the venues list only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ## Creating dataframes for each neighborhood number of venues in the above categories
# ### Toronto

# %%
# Dataframe consisting of the count of Arts&Entertainment venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Arts&Entertainment
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_ArtsEntertainment=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_ArtsEntertainment)
print("Shape of Toronto_ArtsEntertainment", Toronto_ArtsEntertainment.shape)

df_ArtsEntertainment=pd.DataFrame()
df_ArtsEntertainment['ArtsEntertainmentCount']=Toronto_ArtsEntertainment['Neighborhood'].value_counts()
df_ArtsEntertainment=df_ArtsEntertainment.reset_index()
df_ArtsEntertainment=df_ArtsEntertainment.rename(columns={'index':'Neighborhood'})
df_ArtsEntertainment.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_ArtsEntertainment (245, 7)
#             Neighborhood  ArtsEntertainmentCount
# 0   Kensington-Chinatown                      17
# 1             Henry Farm                      17
# 2  Church-Yonge Corridor                      14
# 3   North St. James Town                      13
# 4          Junction Area                       9

# %%
# Dataframe consisting of the count of College venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Colleges
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_Colleges=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_Colleges)
print("Shape of Toronto_Colleges", Toronto_Colleges.shape)

df_Colleges=pd.DataFrame()
df_Colleges['CollegesCount']=Toronto_Colleges['Neighborhood'].value_counts()
df_Colleges=df_Colleges.reset_index()
df_Colleges=df_Colleges.rename(columns={'index':'Neighborhood'})
df_Colleges.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_Colleges (436, 7)
#             Neighborhood  CollegesCount
# 0             University             83
# 1  Church-Yonge Corridor             68
# 2    Bay Street Corridor             46
# 3                  Annex             27
# 4              Moss Park             18

# %%
# Dataframe consisting of the count of Restaurant venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Restaurants
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_Restaurants=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_Restaurants)
print("Shape of Toronto_Restaurants", Toronto_Restaurants.shape)

df_Restaurants=pd.DataFrame()
df_Restaurants['RestaurantsCount']=Toronto_Restaurants['Neighborhood'].value_counts()
df_Restaurants=df_Restaurants.reset_index()
df_Restaurants=df_Restaurants.rename(columns={'index':'Neighborhood'})
df_Restaurants.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_Restaurants (1268, 7)
#             Neighborhood  RestaurantsCount
# 0  Church-Yonge Corridor                80
# 1    Bay Street Corridor                68
# 2   Kensington-Chinatown                51
# 3                Niagara                47
# 4     Yonge and Eglinton                47

# %%
# Dataframe consisting of the count of Night Life venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Night Life
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_NightLife=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_NightLife)
print("Shape of Toronto_NightLife", Toronto_NightLife.shape)

df_NightLife=pd.DataFrame()
df_NightLife['NightLifeCount']=Toronto_NightLife['Neighborhood'].value_counts()
df_NightLife=df_NightLife.reset_index()
df_NightLife=df_NightLife.rename(columns={'index':'Neighborhood'})
df_NightLife.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_NightLife (327, 7)
#             Neighborhood  NightLifeCount
# 0  Church-Yonge Corridor              32
# 1   Kensington-Chinatown              21
# 2                Niagara              20
# 3    Bay Street Corridor              16
# 4        Little Portugal              14

# %%
# Dataframe consisting of the count of Outdoors&Recreational venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Outdoors&Recreation venues
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_OutdoorsRecreation=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_OutdoorsRecreation)
print("Shape of Toronto_OutdoorsRecreation", Toronto_OutdoorsRecreation.shape)

df_OutdoorsRecreation=pd.DataFrame()
df_OutdoorsRecreation['OutdoorsRecreationCount']=Toronto_OutdoorsRecreation['Neighborhood'].value_counts()
df_OutdoorsRecreation=df_OutdoorsRecreation.reset_index()
df_OutdoorsRecreation=df_OutdoorsRecreation.rename(columns={'index':'Neighborhood'})
df_OutdoorsRecreation.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_OutdoorsRecreation (572, 7)
#             Neighborhood  OutdoorsRecreationCount
# 0    Bay Street Corridor                       27
# 1  Church-Yonge Corridor                       24
# 2                Niagara                       22
# 3     Yonge and Eglinton                       13
# 4   North St. James Town                       12

# %%
# Dataframe consisting of the count of Government Buildings in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Government Buildings
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_GovernmentBuilding=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_GovernmentBuilding)
print("Shape of Toronto_GovernmentBuilding", Toronto_GovernmentBuilding.shape)

df_GovernmentBuilding=pd.DataFrame()
df_GovernmentBuilding['GovernmentBuildingCount']=Toronto_GovernmentBuilding['Neighborhood'].value_counts()
df_GovernmentBuilding=df_GovernmentBuilding.reset_index()
df_GovernmentBuilding=df_GovernmentBuilding.rename(columns={'index':'Neighborhood'})
df_GovernmentBuilding.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_GovernmentBuilding (132, 7)
#                  Neighborhood  GovernmentBuildingCount
# 0         Bay Street Corridor                       23
# 1       Church-Yonge Corridor                       10
# 2     Beechborough-Greenbrook                        5
# 3                     Niagara                        4
# 4  Islington-City Centre West                        4

# %%
# Dataframe consisting of the count of Medical Centers in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Medical Center venues
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_MedicalCenter=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_MedicalCenter)
print("Shape of Toronto_MedicalCenter", Toronto_MedicalCenter.shape)

df_MedicalCenter=pd.DataFrame()
df_MedicalCenter['MedicalCenterCount']=Toronto_MedicalCenter['Neighborhood'].value_counts()
df_MedicalCenter=df_MedicalCenter.reset_index()
df_MedicalCenter=df_MedicalCenter.rename(columns={'index':'Neighborhood'})
df_MedicalCenter.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_MedicalCenter (555, 7)
#                Neighborhood  MedicalCenterCount
# 0       Bay Street Corridor                  57
# 1        Yonge and Eglinton                  27
# 2     Church-Yonge Corridor                  17
# 3  Playter Estates-Danforth                  16
# 4                L'Amoreaux                  15

# %%
# Dataframe consisting of the count of Spiritual Centers in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Spiritual Center venues
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_SpiritualCenter=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_SpiritualCenter)
print("Shape of Toronto_SpiritualCenter", Toronto_SpiritualCenter.shape)

df_SpiritualCenter=pd.DataFrame()
df_SpiritualCenter['SpiritualCenterCount']=Toronto_SpiritualCenter['Neighborhood'].value_counts()
df_SpiritualCenter=df_SpiritualCenter.reset_index()
df_SpiritualCenter=df_SpiritualCenter.rename(columns={'index':'Neighborhood'})
df_SpiritualCenter.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_SpiritualCenter (239, 7)
#         Neighborhood  SpiritualCenterCount
# 0  Trinity-Bellwoods                     8
# 1              Annex                     7
# 2         University                     7
# 3        New Toronto                     7
# 4          Moss Park                     6

# %%
# Dataframe consisting of the count of Grocery Stores in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Grocery Stores
#then assigning to a new column the number of venues returned for each neighborhood
Toronto_FoodShop=getNearbyVenues(names=dfToronto['Neighborhood'], latitudes=dfToronto['Latitude'], longitudes=dfToronto['Longitude'], categoryID=id_FoodShop)
print("Shape of Toronto_FoodShop", Toronto_FoodShop.shape)

df_FoodShop=pd.DataFrame()
df_FoodShop['FoodShopCount']=Toronto_FoodShop['Neighborhood'].value_counts()
df_FoodShop=df_FoodShop.reset_index()
df_FoodShop=df_FoodShop.rename(columns={'index':'Neighborhood'})
df_FoodShop.head()
# Out:
# Agincourt North
# Agincourt South-Malvern West
# Alderwood
# Annex
# Banbury-Don Mills
# Bathurst Manor
# Bay Street Corridor
# Bayview Village
# Bayview Woods-Steeles
# Bedford Park-Nortown
# Beechborough-Greenbrook
# Bendale
# Birchcliffe-Cliffside
# Black Creek
# Blake-Jones
# Briar Hill-Belgravia
# Bridle Path-Sunnybrook-York Mills
# Broadview North
# Brookhaven-Amesbury
# Cabbagetown-South St. James Town
# Caledonia-Fairbank
# Casa Loma
# Centennial Scarborough
# Church-Yonge Corridor
# Clairlea-Birchmount
# Clanton Park
# Cliffcrest
# Corso Italia-Davenport
# Danforth - East York
# Don Valley Village
# Dorset Park
# Dovercourt-Wallace Emerson-Junction
# Downsview-Roding-CFB
# Dufferin Grove
# East End-Danforth
# Edenbridge-Humber Valley
# Eglinton East
# Elms-Old Rexdale
# Englemount-Lawrence
# Eringate-Centennial-West Deane
# Etobicoke West Mall
# Flemingdon Park
# Forest Hill North
# Forest Hill South
# Glenfield-Jane Heights
# Greenwood-Coxwell
# Guildwood
# Henry Farm
# High Park North
# High Park-Swansea
# Highland Creek
# Hillcrest Village
# Humber Heights-Westmount
# Humber Summit
# Humbermede
# Humewood-Cedarvale
# Ionview
# Islington-City Centre West
# Junction Area
# Keelesdale-Eglinton West
# Kennedy Park
# Kensington-Chinatown
# Kingsview Village-The Westway
# Kingsway South
# L'Amoreaux
# Lambton Baby Point
# Lansing-Westgate
# Lawrence Park North
# Lawrence Park South
# Leaside-Bennington
# Little Portugal
# Long Branch
# Malvern
# Maple Leaf
# Markland Wood
# Milliken
# Mimico
# Morningside
# Moss Park
# Mount Dennis
# Mount Olive-Silverstone-Jamestown
# Mount Pleasant East
# Mount Pleasant West
# New Toronto
# Newtonbrook East
# Newtonbrook West
# Niagara
# North Riverdale
# North St. James Town
# O'Connor-Parkview
# Oakridge
# Oakwood Village
# Old East York
# Palmerston-Little Italy
# Parkwoods-Donalda
# Pelmo Park-Humberlea
# Playter Estates-Danforth
# Pleasant View
# Princess-Rosethorn
# Regent Park
# Rexdale-Kipling
# Rockcliffe-Smythe
# Roncesvalles
# Rosedale-Moore Park
# Rouge
# Runnymede-Bloor West Village
# Rustic
# Scarborough Village
# South Riverdale
# South Parkdale
# St. Andrew-Windfields
# Steeles
# Stonegate-Queensway
# Tam O'Shanter-Sullivan
# The Beaches
# Thistletown-Beaumond Heights
# Thorncliffe Park
# Trinity-Bellwoods
# University
# Victoria Village
# Waterfront Communities-The Island
# West Hill
# West Humber-Clairville
# Westminster-Branson
# Weston
# Weston-Pellam Park
# Wexford-Maryvale
# Willowdale East
# Willowdale West
# Willowridge-Martingrove-Richview
# Woburn
# Woodbine Corridor
# Woodbine-Lumsden
# Wychwood
# Yonge and Eglinton
# Yonge-St.Clair
# York University Heights
# Yorkdale-Glen Park
# Shape of Toronto_FoodShop (381, 7)
#             Neighborhood  FoodShopCount
# 0    Bay Street Corridor             30
# 1   Kensington-Chinatown             29
# 2  Church-Yonge Corridor             23
# 3     Yonge and Eglinton             14
# 4         Dufferin Grove             12

# %%
# Merging the categories dataframes with the Toronto dataframe and replacing the NaN values with 0
merged_dfToronto=pd.merge(left=dfToronto, right=df_ArtsEntertainment, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_Colleges, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_Restaurants, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_NightLife, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_OutdoorsRecreation, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_GovernmentBuilding, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_MedicalCenter, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_SpiritualCenter, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfToronto=pd.merge(left=merged_dfToronto, right=df_FoodShop, how='left', left_on='Neighborhood', right_on='Neighborhood')

merged_dfToronto=merged_dfToronto.fillna(0)
merged_dfToronto.head()
# Out:
#                    Neighborhood              Borough  TotalCrimes  Longitude  \
# 0               Agincourt North          Scarborough          363  -79.26707
# 1  Agincourt South-Malvern West          Scarborough          478  -79.26935
# 2                     Alderwood            Etobicoke          204  -79.54116
# 3                         Annex  Old City of Toronto          943  -79.40280
# 4             Banbury-Don Mills           North York          403  -79.34852
#
#    Latitude  ArtsEntertainmentCount  CollegesCount  RestaurantsCount  \
# 0  43.80930                     1.0            0.0              14.0
# 1  43.78736                     1.0            6.0              20.0
# 2  43.60496                     1.0            1.0               4.0
# 3  43.66936                     4.0           27.0              26.0
# 4  43.74041                     0.0            0.0               2.0
#
#    NightLifeCount  OutdoorsRecreationCount  GovernmentBuildingCount  \
# 0             1.0                      2.0                      0.0
# 1             3.0                      3.0                      1.0
# 2             0.0                      4.0                      0.0
# 3             7.0                      9.0                      3.0
# 4             0.0                      1.0                      0.0
#
#    MedicalCenterCount  SpiritualCenterCount  FoodShopCount
# 0                 6.0                   0.0            4.0
# 1                 8.0                   2.0            4.0
# 2                 4.0                   0.0            1.0
# 3                10.0                   7.0            6.0
# 4                 1.0                   1.0            1.0

# %% [markdown]
# ### London

# %%
# Dataframe consisting of the count of Arts&Entertainment venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Arts&Entertainment
#then assigning to a new column the number of venues returned for each neighborhood
London_ArtsEntertainment=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_ArtsEntertainment)
print("Shape of London_ArtsEntertainment", London_ArtsEntertainment.shape)

df_ArtsEntertainment=pd.DataFrame()
df_ArtsEntertainment['ArtsEntertainmentCount']=London_ArtsEntertainment['Neighborhood'].value_counts()
df_ArtsEntertainment=df_ArtsEntertainment.reset_index()
df_ArtsEntertainment=df_ArtsEntertainment.rename(columns={'index':'Neighborhood'})
df_ArtsEntertainment.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_ArtsEntertainment (1630, 7)
#        Neighborhood  ArtsEntertainmentCount
# 0     Charing Cross                      75
# 1           Holland                      70
# 2         St Luke's                      68
# 3  Ravenscourt Park                      45
# 4        Bloomsbury                      44

# %%
# Dataframe consisting of the count of College venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Colleges
#then assigning to a new column the number of venues returned for each neighborhood
London_Colleges=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_Colleges)
print("Shape of London_Colleges", London_Colleges.shape)

df_Colleges=pd.DataFrame()
df_Colleges['CollegesCount']=London_Colleges['Neighborhood'].value_counts()
df_Colleges=df_Colleges.reset_index()
df_Colleges=df_Colleges.rename(columns={'index':'Neighborhood'})
df_Colleges.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_Colleges (1620, 7)
#        Neighborhood  CollegesCount
# 0           Aldwych             77
# 1       Forest Hill             70
# 2          Thornton             69
# 3        Bloomsbury             62
# 4  Ravenscourt Park             56

# %%
# Dataframe consisting of the count of Restaurant venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Restaurants
#then assigning to a new column the number of venues returned for each neighborhood
London_Restaurants=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_Restaurants)
print("Shape of London_Restaurants", London_Restaurants.shape)

df_Restaurants=pd.DataFrame()
df_Restaurants['RestaurantsCount']=London_Restaurants['Neighborhood'].value_counts()
df_Restaurants=df_Restaurants.reset_index()
df_Restaurants=df_Restaurants.rename(columns={'index':'Neighborhood'})
df_Restaurants.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_Restaurants (6387, 7)
#   Neighborhood  RestaurantsCount
# 0    St Luke's               100
# 1   Cathedrals               100
# 2      Weavers               100
# 3     Homerton                80
# 4      Holland                78

# %%
# Dataframe consisting of the count of Night Life venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Night Life
#then assigning to a new column the number of venues returned for each neighborhood
London_NightLife=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_NightLife)
print("Shape of London_NightLife", London_NightLife.shape)

df_NightLife=pd.DataFrame()
df_NightLife['NightLifeCount']=London_NightLife['Neighborhood'].value_counts()
df_NightLife=df_NightLife.reset_index()
df_NightLife=df_NightLife.rename(columns={'index':'Neighborhood'})
df_NightLife.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_NightLife (3168, 7)
#                      Neighborhood  NightLifeCount
# 0                       St Luke's             100
# 1                      Cathedrals              73
# 2  Camden Town with Primrose Hill              65
# 3                         Weavers              58
# 4                         Holland              53

# %%
# Dataframe consisting of the count of Outdoors&Recreational venues in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Outdoors&Recreation venues
#then assigning to a new column the number of venues returned for each neighborhood
London_OutdoorsRecreation=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_OutdoorsRecreation)
print("Shape of London_OutdoorsRecreation", London_OutdoorsRecreation.shape)

df_OutdoorsRecreation=pd.DataFrame()
df_OutdoorsRecreation['OutdoorsRecreationCount']=London_OutdoorsRecreation['Neighborhood'].value_counts()
df_OutdoorsRecreation=df_OutdoorsRecreation.reset_index()
df_OutdoorsRecreation=df_OutdoorsRecreation.rename(columns={'index':'Neighborhood'})
df_OutdoorsRecreation.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_OutdoorsRecreation (2406, 7)
#      Neighborhood  OutdoorsRecreationCount
# 0         Holland                       35
# 1       St Luke's                       34
# 2    Canary Wharf                       33
# 3   Charing Cross                       33
# 4  St John's Wood                       32

# %%
# Dataframe consisting of the count of Government Buildings in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Government Buildings
#then assigning to a new column the number of venues returned for each neighborhood
London_GovernmentBuilding=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_GovernmentBuilding)
print("Shape of London_GovernmentBuilding", London_GovernmentBuilding.shape)

df_GovernmentBuilding=pd.DataFrame()
df_GovernmentBuilding['GovernmentBuildingCount']=London_GovernmentBuilding['Neighborhood'].value_counts()
df_GovernmentBuilding=df_GovernmentBuilding.reset_index()
df_GovernmentBuilding=df_GovernmentBuilding.rename(columns={'index':'Neighborhood'})
df_GovernmentBuilding.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_GovernmentBuilding (1061, 7)
#               Neighborhood  GovernmentBuildingCount
# 0                Churchill                       70
# 1              Rotherhithe                       61
# 2               Abbey Road                       61
# 3               Maida Vale                       57
# 4  Wormholt and White City                       52

# %%
# Dataframe consisting of the count of Medical Centers in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Medical Center venues
#then assigning to a new column the number of venues returned for each neighborhood
London_MedicalCenter=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_MedicalCenter)
print("Shape of London_MedicalCenter", London_MedicalCenter.shape)

df_MedicalCenter=pd.DataFrame()
df_MedicalCenter['MedicalCenterCount']=London_MedicalCenter['Neighborhood'].value_counts()
df_MedicalCenter=df_MedicalCenter.reset_index()
df_MedicalCenter=df_MedicalCenter.rename(columns={'index':'Neighborhood'})
df_MedicalCenter.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_MedicalCenter (1358, 7)
#   Neighborhood  MedicalCenterCount
# 0     Mile End                  65
# 1  Forest Hill                  29
# 2    St Luke's                  19
# 3   Bloomsbury                  16
# 4   Paddington                  15

# %%
# Dataframe consisting of the count of Spiritual Centers in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Spiritual Center venues
#then assigning to a new column the number of venues returned for each neighborhood
London_SpiritualCenter=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_SpiritualCenter)
print("Shape of London_SpiritualCenter", London_SpiritualCenter.shape)

df_SpiritualCenter=pd.DataFrame()
df_SpiritualCenter['SpiritualCenterCount']=London_SpiritualCenter['Neighborhood'].value_counts()
df_SpiritualCenter=df_SpiritualCenter.reset_index()
df_SpiritualCenter=df_SpiritualCenter.rename(columns={'index':'Neighborhood'})
df_SpiritualCenter.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_SpiritualCenter (816, 7)
#   Neighborhood  SpiritualCenterCount
# 0    St Luke's                    16
# 1     Ferndale                    14
# 2      Holland                    11
# 3     Thornton                    10
# 4   Herne Hill                     9

# %%
# Dataframe consisting of the count of Grocery Stores in the neighborhoods, resulted 
#by using the getNearbyVenues function with the Foursquare category ID for Grocery Stores
#then assigning to a new column the number of venues returned for each neighborhood
London_FoodShop=getNearbyVenues(names=dfLondon['Neighborhood'], latitudes=dfLondon['Latitude'], longitudes=dfLondon['Longitude'], categoryID=id_FoodShop)
print("Shape of London_FoodShop", London_FoodShop.shape)

df_FoodShop=pd.DataFrame()
df_FoodShop['FoodShopCount']=London_FoodShop['Neighborhood'].value_counts()
df_FoodShop=df_FoodShop.reset_index()
df_FoodShop=df_FoodShop.rename(columns={'index':'Neighborhood'})
df_FoodShop.head()
# Out:
# Abbey Road
# Addison
# Aldwych
# Angel
# Archway
# Avonmore and Brook Green
# Balham
# Bankside
# Barnsbury
# Battersea
# Bayswater
# Belgravia
# Bellingham
# Belsize
# Bermondsey
# Bethnal Green
# Bishop's
# Blackheath
# Blackheath Westcombe
# Blackwall
# Blackwall & Cubitt Town
# Bloomsbury
# Bow East
# Bow West
# Brixton Hill
# Brockley
# Bromley North
# Bromley South
# Brompton & Hans Town
# Brownswood
# Bryanston and Dorset Square
# Caledonian
# Camberwell Green
# Cambridge Heath
# Camden Town with Primrose Hill
# Canary Wharf
# Canonbury
# Cantelowes
# Catford South
# Cathedrals
# Cazenove
# Chalk Farm
# Charing Cross
# Charlton
# Chelsea Riverside
# Chinbrook
# Church Street
# Churchill
# Clapham Common
# Clapham Town
# Clerkenwell
# Clissold
# Coldharbour
# Coldharbour and New Eltham
# College
# College Park and Old Oak
# Courtfield
# Cricklewood
# Crofton Park
# Cubitt Town
# Dalston
# De Beauvoir
# Denmark Hill
# Deptford
# Downham
# Dulwich
# Earl's Court
# Earlsfield
# East Dulwich
# East Putney
# East Walworth
# Elephant and Castle
# Eltham North
# Eltham South
# Eltham West
# Fairfield
# Farringdon
# Ferndale
# Finsbury Park
# Fitzrovia
# Forest Hill
# Fortune Green
# Frognal and Fitzjohns
# Fulham Broadway
# Fulham Reach
# Furzedown
# Gipsy Hill
# Glyndon
# Gospel Oak
# Grange
# Greenwich West
# Grove Park
# Hackney Central
# Hackney Downs
# Hackney Marshes
# Hackney Wick
# Haggerston
# Hammersmith Broadway
# Hampstead Town
# Harrow Road
# Haverstock
# Herne Hill
# Highbury East
# Highgate
# Hither Green
# Holborn and Covent Garden
# Holland
# Holland Park
# Holloway
# Homerton
# Honor Oak
# Horn Park
# Hoxton
# Hoxton East & Shoreditch
# Hoxton West
# Hyde Park
# Island Gardens
# Kennington
# Kensington
# Kentish Town
# Kidbrooke with Hornfair
# Kilburn
# King's Cross
# King's Park
# Knight's Hill
# Knightsbridge and Belgravia
# Ladywell
# Lancaster Gate
# Lansbury
# Larkhall
# Lea Bridge
# Lee Green
# Limehouse
# Lisson Grove
# Little Venice
# London Fields
# Lower Clapton
# Maida Vale
# Manor House
# Marylebone High Street
# Maze Hill
# Middle Park and Sutcliffe
# Mile End
# Millbank
# Millwall
# New Cross
# New Eltham
# Newington
# Nightingale
# Nine Elms
# North Kensington
# Nunhead
# Old Ford
# Old Oak Common
# Oval
# Paddington
# Palace Riverside
# Parsons Green and Walham
# Peckham
# Peckham Rye
# Peninsula
# Pentonville
# Perry Vale
# Pimlico
# Plumstead
# Poplar
# Primrose Hill
# Putney
# Queen's Gate
# Queenstown
# Ratcliff
# Ravenscourt Park
# Regent's Park
# Regent's Park
# Riverside
# Roehampton and Putney Heath
# Rotherhithe
# Royal Hospital
# Rushey Green
# Sands End
# Shacklewell
# Shadwell
# Shepherd's Bush Green
# Shooters Hill
# Somerstown
# South Bermondsey
# South Camberwell
# South Hackney
# South Kensington
# Southend
# Southfields
# Spitalfields & Banglatown
# Springfield
# St Giles
# St John's Wood
# St Johns
# St Luke's
# St Pancras
# St. Dunstan's
# St. George's
# St. James's
# St. Katharine's & Wapping
# St. Leonard's
# St. Mary's
# St. Mary's Park
# St. Pancras and Somers Town
# St. Peter's
# Stamford Hill
# Stamford Hill West
# Stepney Green
# Stockwell
# Stoke Newington
# Streatham Hill
# Streatham South
# Streatham Wells
# Surrey Docks
# Swiss Cottage
# Sydenham
# Sydenham Hill
# Telegraph Hill
# Temple
# Thamesfield
# Thamesmead Moorings
# Thornton
# Thurlow Park
# Tollington
# Tower Hill
# Tufnell Park
# Tulse Hill
# Upper Clapton
# Upper Holloway
# Vauxhall
# Victoria
# Village
# Vincent Square
# Wandsworth Common
# Wapping
# Weavers
# Well Hall
# West Brompton
# West Hampstead
# West Hill
# West Kensington
# West Norwood
# West Putney
# Westbourne
# Westcombe Park
# Whitechapel
# Whitefoot
# Woodberry Down
# Woolwich Common
# Woolwich Riverside
# Wormholt and White City
# Wormwood Scrubs
# Evelyn and Lewisham Central
# Islington
# Kensington and Chelsea
# Town, Askew and Munster
# Wandsworth
# Westminster
# Shape of London_FoodShop (2020, 7)
#   Neighborhood  FoodShopCount
# 0   Cathedrals             49
# 1      Weavers             46
# 2      College             43
# 3      Holland             42
# 4     Bankside             37

# %%
# Merging the categories dataframes with the London dataframe and replacing the NaN values with 0
merged_dfLondon=pd.merge(left=dfLondon, right=df_ArtsEntertainment, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_Colleges, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_Restaurants, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_NightLife, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_OutdoorsRecreation, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_GovernmentBuilding, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_MedicalCenter, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_SpiritualCenter, how='left', left_on='Neighborhood', right_on='Neighborhood')
merged_dfLondon=pd.merge(left=merged_dfLondon, right=df_FoodShop, how='left', left_on='Neighborhood', right_on='Neighborhood')

merged_dfLondon=merged_dfLondon.fillna(0)
merged_dfLondon.head()
# Out:
#   Neighborhood                 Borough  TotalCrimes  Longitude   Latitude  \
# 0   Abbey Road             Westminster       1215.0  -0.127197  51.497657
# 1      Addison  Hammersmith and Fulham       2634.0  -0.212880  51.482600
# 2      Aldwych             Westminster          0.0  -0.118607  51.512653
# 3        Angel               Islington          0.0  -0.106260  51.532020
# 4      Archway               Islington          0.0  -0.134922  51.565748
#
#    ArtsEntertainmentCount  CollegesCount  RestaurantsCount  NightLifeCount  \
# 0                    17.0            5.0              50.0            20.0
# 1                     3.0            3.0              15.0             4.0
# 2                    39.0           77.0              61.0            46.0
# 3                    14.0           11.0              66.0            23.0
# 4                     2.0            4.0              21.0            10.0
#
#    OutdoorsRecreationCount  GovernmentBuildingCount  MedicalCenterCount  \
# 0                     19.0                     61.0                 2.0
# 1                      8.0                      0.0                10.0
# 2                     26.0                     12.0                11.0
# 3                     19.0                      4.0                 8.0
# 4                      4.0                      5.0                 4.0
#
#    SpiritualCenterCount  FoodShopCount
# 0                   8.0            7.0
# 1                   4.0            3.0
# 2                   8.0           24.0
# 3                   3.0           22.0
# 4                   5.0            9.0

# %% [markdown]
# ## Normalizing the data of the venues dataframe for more accurate results
# ### Toronto

# %%
# Creating a new dataframe that will have only the neighborhoods and categories columns
new_Torontodf=merged_dfToronto
new_Torontodf.drop(['Borough', 'Longitude', 'Latitude'], axis='columns', inplace=True)
new_Torontodf.head()
# Out:
#                    Neighborhood  TotalCrimes  ArtsEntertainmentCount  \
# 0               Agincourt North          363                     1.0
# 1  Agincourt South-Malvern West          478                     1.0
# 2                     Alderwood          204                     1.0
# 3                         Annex          943                     4.0
# 4             Banbury-Don Mills          403                     0.0
#
#    CollegesCount  RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0            0.0              14.0             1.0                      2.0
# 1            6.0              20.0             3.0                      3.0
# 2            1.0               4.0             0.0                      4.0
# 3           27.0              26.0             7.0                      9.0
# 4            0.0               2.0             0.0                      1.0
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                      0.0                 6.0                   0.0
# 1                      1.0                 8.0                   2.0
# 2                      0.0                 4.0                   0.0
# 3                      3.0                10.0                   7.0
# 4                      0.0                 1.0                   1.0
#
#    FoodShopCount
# 0            4.0
# 1            4.0
# 2            1.0
# 3            6.0
# 4            1.0

# %%
# Creating a dataframe that will store the neighborhood values from the Toronto dataframe
df_neigh=pd.DataFrame()
df_neigh['Neighborhood']=new_Torontodf['Neighborhood']
df_neigh.head()
# Out:
#                    Neighborhood
# 0               Agincourt North
# 1  Agincourt South-Malvern West
# 2                     Alderwood
# 3                         Annex
# 4             Banbury-Don Mills

# %%
# Creating a new dataframe that has only the columns with category counts
df_cat=pd.DataFrame()
df_cat=new_Torontodf
df_cat.drop(['Neighborhood'], axis='columns', inplace=True)
df_cat.head()
# Out:
#    TotalCrimes  ArtsEntertainmentCount  CollegesCount  RestaurantsCount  \
# 0          363                     1.0            0.0              14.0
# 1          478                     1.0            6.0              20.0
# 2          204                     1.0            1.0               4.0
# 3          943                     4.0           27.0              26.0
# 4          403                     0.0            0.0               2.0
#
#    NightLifeCount  OutdoorsRecreationCount  GovernmentBuildingCount  \
# 0             1.0                      2.0                      0.0
# 1             3.0                      3.0                      1.0
# 2             0.0                      4.0                      0.0
# 3             7.0                      9.0                      3.0
# 4             0.0                      1.0                      0.0
#
#    MedicalCenterCount  SpiritualCenterCount  FoodShopCount
# 0                 6.0                   0.0            4.0
# 1                 8.0                   2.0            4.0
# 2                 4.0                   0.0            1.0
# 3                10.0                   7.0            6.0
# 4                 1.0                   1.0            1.0

# %%
# Normalizing the values of the venue category counts for more accurate clustering results
norm=pd.DataFrame(df_cat)
min_max_scaler=preprocessing.MinMaxScaler()
x_scaled=min_max_scaler.fit_transform(norm)
Cat_normalized=pd.DataFrame(x_scaled, columns=norm.columns)
Cat_normalized.head()
# Out:
#    TotalCrimes  ArtsEntertainmentCount  CollegesCount  RestaurantsCount  \
# 0     0.114524                0.058824       0.000000             0.175
# 1     0.164985                0.058824       0.072289             0.250
# 2     0.044756                0.058824       0.012048             0.050
# 3     0.369022                0.235294       0.325301             0.325
# 4     0.132075                0.000000       0.000000             0.025
#
#    NightLifeCount  OutdoorsRecreationCount  GovernmentBuildingCount  \
# 0         0.03125                 0.074074                 0.000000
# 1         0.09375                 0.111111                 0.043478
# 2         0.00000                 0.148148                 0.000000
# 3         0.21875                 0.333333                 0.130435
# 4         0.00000                 0.037037                 0.000000
#
#    MedicalCenterCount  SpiritualCenterCount  FoodShopCount
# 0            0.105263                 0.000       0.133333
# 1            0.140351                 0.250       0.133333
# 2            0.070175                 0.000       0.033333
# 3            0.175439                 0.875       0.200000
# 4            0.017544                 0.125       0.033333

# %%
# Remaking the dataframe of Toronto neighborhoods and the normalized venue categories columns
merged_dfT=pd.merge(left=df_neigh, right=Cat_normalized, how='left', left_on=df_neigh.index, right_on=Cat_normalized.index)
merged_dfT.drop(['key_0'], axis='columns', inplace=True)
merged_dfT.head()
# Out:
#                    Neighborhood  TotalCrimes  ArtsEntertainmentCount  \
# 0               Agincourt North     0.114524                0.058824
# 1  Agincourt South-Malvern West     0.164985                0.058824
# 2                     Alderwood     0.044756                0.058824
# 3                         Annex     0.369022                0.235294
# 4             Banbury-Don Mills     0.132075                0.000000
#
#    CollegesCount  RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0       0.000000             0.175         0.03125                 0.074074
# 1       0.072289             0.250         0.09375                 0.111111
# 2       0.012048             0.050         0.00000                 0.148148
# 3       0.325301             0.325         0.21875                 0.333333
# 4       0.000000             0.025         0.00000                 0.037037
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                 0.000000            0.105263                 0.000
# 1                 0.043478            0.140351                 0.250
# 2                 0.000000            0.070175                 0.000
# 3                 0.130435            0.175439                 0.875
# 4                 0.000000            0.017544                 0.125
#
#    FoodShopCount
# 0       0.133333
# 1       0.133333
# 2       0.033333
# 3       0.200000
# 4       0.033333

# %% [markdown]
# ### London

# %%
# Creating a new dataframe that will have only the neighborhoods and categories columns
new_Londondf=merged_dfLondon
new_Londondf.drop(['Borough', 'Longitude', 'Latitude'], axis='columns', inplace=True)
new_Londondf.head()
# Out:
#   Neighborhood  TotalCrimes  ArtsEntertainmentCount  CollegesCount  \
# 0   Abbey Road       1215.0                    17.0            5.0
# 1      Addison       2634.0                     3.0            3.0
# 2      Aldwych          0.0                    39.0           77.0
# 3        Angel          0.0                    14.0           11.0
# 4      Archway          0.0                     2.0            4.0
#
#    RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0              50.0            20.0                     19.0
# 1              15.0             4.0                      8.0
# 2              61.0            46.0                     26.0
# 3              66.0            23.0                     19.0
# 4              21.0            10.0                      4.0
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                     61.0                 2.0                   8.0
# 1                      0.0                10.0                   4.0
# 2                     12.0                11.0                   8.0
# 3                      4.0                 8.0                   3.0
# 4                      5.0                 4.0                   5.0
#
#    FoodShopCount
# 0            7.0
# 1            3.0
# 2           24.0
# 3           22.0
# 4            9.0

# %%
# Creating a dataframe that will store the neighborhood values from the London dataframe
df_neigh=pd.DataFrame()
df_neigh['Neighborhood']=new_Londondf['Neighborhood']
df_neigh.head()
# Out:
#   Neighborhood
# 0   Abbey Road
# 1      Addison
# 2      Aldwych
# 3        Angel
# 4      Archway

# %%
# Creating a new dataframe that has only the columns with category counts
df_cat=pd.DataFrame()
df_cat=new_Londondf
df_cat.drop(['Neighborhood'], axis='columns', inplace=True)
df_cat.head()
# Out:
#    TotalCrimes  ArtsEntertainmentCount  CollegesCount  RestaurantsCount  \
# 0       1215.0                    17.0            5.0              50.0
# 1       2634.0                     3.0            3.0              15.0
# 2          0.0                    39.0           77.0              61.0
# 3          0.0                    14.0           11.0              66.0
# 4          0.0                     2.0            4.0              21.0
#
#    NightLifeCount  OutdoorsRecreationCount  GovernmentBuildingCount  \
# 0            20.0                     19.0                     61.0
# 1             4.0                      8.0                      0.0
# 2            46.0                     26.0                     12.0
# 3            23.0                     19.0                      4.0
# 4            10.0                      4.0                      5.0
#
#    MedicalCenterCount  SpiritualCenterCount  FoodShopCount
# 0                 2.0                   8.0            7.0
# 1                10.0                   4.0            3.0
# 2                11.0                   8.0           24.0
# 3                 8.0                   3.0           22.0
# 4                 4.0                   5.0            9.0

# %%
# Normalizing the values of the venue category counts for more accurate clustering results
norm=pd.DataFrame(df_cat)
min_max_scaler=preprocessing.MinMaxScaler()
x_scaled=min_max_scaler.fit_transform(norm)
Cat_normalized=pd.DataFrame(x_scaled, columns=norm.columns)
Cat_normalized.head()
# Out:
#    TotalCrimes  ArtsEntertainmentCount  CollegesCount  RestaurantsCount  \
# 0     0.037725                0.226667       0.064935              0.50
# 1     0.081783                0.040000       0.038961              0.15
# 2     0.000000                0.520000       1.000000              0.61
# 3     0.000000                0.186667       0.142857              0.66
# 4     0.000000                0.026667       0.051948              0.21
#
#    NightLifeCount  OutdoorsRecreationCount  GovernmentBuildingCount  \
# 0            0.20                 0.542857                 0.871429
# 1            0.04                 0.228571                 0.000000
# 2            0.46                 0.742857                 0.171429
# 3            0.23                 0.542857                 0.057143
# 4            0.10                 0.114286                 0.071429
#
#    MedicalCenterCount  SpiritualCenterCount  FoodShopCount
# 0            0.030769                0.5000       0.142857
# 1            0.153846                0.2500       0.061224
# 2            0.169231                0.5000       0.489796
# 3            0.123077                0.1875       0.448980
# 4            0.061538                0.3125       0.183673

# %%
# Remaking the dataframe of London neighborhoods and the normalized venue categories columns
merged_dfL=pd.merge(left=df_neigh, right=Cat_normalized, how='left', left_on=df_neigh.index, right_on=Cat_normalized.index)
merged_dfL.drop(['key_0'], axis='columns', inplace=True)
merged_dfL.head()
# Out:
#   Neighborhood  TotalCrimes  ArtsEntertainmentCount  CollegesCount  \
# 0   Abbey Road     0.037725                0.226667       0.064935
# 1      Addison     0.081783                0.040000       0.038961
# 2      Aldwych     0.000000                0.520000       1.000000
# 3        Angel     0.000000                0.186667       0.142857
# 4      Archway     0.000000                0.026667       0.051948
#
#    RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0              0.50            0.20                 0.542857
# 1              0.15            0.04                 0.228571
# 2              0.61            0.46                 0.742857
# 3              0.66            0.23                 0.542857
# 4              0.21            0.10                 0.114286
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                 0.871429            0.030769                0.5000
# 1                 0.000000            0.153846                0.2500
# 2                 0.171429            0.169231                0.5000
# 3                 0.057143            0.123077                0.1875
# 4                 0.071429            0.061538                0.3125
#
#    FoodShopCount
# 0       0.142857
# 1       0.061224
# 2       0.489796
# 3       0.448980
# 4       0.183673

# %% [markdown]
# ## Ordering the most common venues and the crimes data in each neighborhood

# %%
# Function for most common venues
def return_most_common_venues(row, top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:top_venues]

# %% [markdown]
# ### Toronto

# %%
# Sorting the venue categories in each neighborhood
top_venues = 10
indicators = ['st', 'nd', 'rd']

# Create columns according to the number of venue categories
columns = ['Neighborhood']
for ind in np.arange(top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# New dataframe for sorted venues
Toronto_venues_sorted = pd.DataFrame(columns=columns)
Toronto_venues_sorted['Neighborhood'] = merged_dfT['Neighborhood']

for ind in np.arange(merged_dfT.shape[0]):
    Toronto_venues_sorted.iloc[ind, 1:] = return_most_common_venues(merged_dfT.iloc[ind, :], top_venues)

Toronto_venues_sorted.head()
# Out:
#                    Neighborhood    1st Most Common Venue  \
# 0               Agincourt North         RestaurantsCount
# 1  Agincourt South-Malvern West     SpiritualCenterCount
# 2                     Alderwood  OutdoorsRecreationCount
# 3                         Annex     SpiritualCenterCount
# 4             Banbury-Don Mills              TotalCrimes
#
#   2nd Most Common Venue    3rd Most Common Venue 4th Most Common Venue  \
# 0         FoodShopCount              TotalCrimes    MedicalCenterCount
# 1      RestaurantsCount              TotalCrimes    MedicalCenterCount
# 2    MedicalCenterCount   ArtsEntertainmentCount      RestaurantsCount
# 3           TotalCrimes  OutdoorsRecreationCount         CollegesCount
# 4  SpiritualCenterCount  OutdoorsRecreationCount         FoodShopCount
#
#      5th Most Common Venue    6th Most Common Venue    7th Most Common Venue  \
# 0  OutdoorsRecreationCount   ArtsEntertainmentCount           NightLifeCount
# 1            FoodShopCount  OutdoorsRecreationCount           NightLifeCount
# 2              TotalCrimes            FoodShopCount            CollegesCount
# 3         RestaurantsCount   ArtsEntertainmentCount           NightLifeCount
# 4         RestaurantsCount       MedicalCenterCount  GovernmentBuildingCount
#
#   8th Most Common Venue    9th Most Common Venue   10th Most Common Venue
# 0  SpiritualCenterCount  GovernmentBuildingCount            CollegesCount
# 1         CollegesCount   ArtsEntertainmentCount  GovernmentBuildingCount
# 2  SpiritualCenterCount  GovernmentBuildingCount           NightLifeCount
# 3         FoodShopCount       MedicalCenterCount  GovernmentBuildingCount
# 4        NightLifeCount            CollegesCount   ArtsEntertainmentCount

# %% [markdown]
# ### London

# %%
# Sorting the venue categories in each neighborhood
top_venues = 10
indicators = ['st', 'nd', 'rd']

# Create columns according to the number of venue categories
columns = ['Neighborhood']
for ind in np.arange(top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# New dataframe for sorted venues
London_venues_sorted = pd.DataFrame(columns=columns)
London_venues_sorted['Neighborhood'] = merged_dfL['Neighborhood']

for ind in np.arange(merged_dfL.shape[0]):
    London_venues_sorted.iloc[ind, 1:] = return_most_common_venues(merged_dfL.iloc[ind, :], top_venues)

London_venues_sorted.head()
# Out:
#   Neighborhood    1st Most Common Venue    2nd Most Common Venue  \
# 0   Abbey Road  GovernmentBuildingCount  OutdoorsRecreationCount
# 1      Addison     SpiritualCenterCount  OutdoorsRecreationCount
# 2      Aldwych            CollegesCount  OutdoorsRecreationCount
# 3        Angel         RestaurantsCount  OutdoorsRecreationCount
# 4      Archway     SpiritualCenterCount         RestaurantsCount
#
#   3rd Most Common Venue    4th Most Common Venue   5th Most Common Venue  \
# 0  SpiritualCenterCount         RestaurantsCount  ArtsEntertainmentCount
# 1    MedicalCenterCount         RestaurantsCount             TotalCrimes
# 2      RestaurantsCount   ArtsEntertainmentCount    SpiritualCenterCount
# 3         FoodShopCount           NightLifeCount    SpiritualCenterCount
# 4         FoodShopCount  OutdoorsRecreationCount          NightLifeCount
#
#      6th Most Common Venue 7th Most Common Venue    8th Most Common Venue  \
# 0           NightLifeCount         FoodShopCount            CollegesCount
# 1            FoodShopCount        NightLifeCount   ArtsEntertainmentCount
# 2            FoodShopCount        NightLifeCount  GovernmentBuildingCount
# 3   ArtsEntertainmentCount         CollegesCount       MedicalCenterCount
# 4  GovernmentBuildingCount    MedicalCenterCount            CollegesCount
#
#      9th Most Common Venue   10th Most Common Venue
# 0              TotalCrimes       MedicalCenterCount
# 1            CollegesCount  GovernmentBuildingCount
# 2       MedicalCenterCount              TotalCrimes
# 3  GovernmentBuildingCount              TotalCrimes
# 4   ArtsEntertainmentCount              TotalCrimes

# %% [markdown]
# ## Using Kmeans algorithm to cluster the neighborhoods based on venues frequency
# ### Toronto

# %%
# Setting the number of clusters and performing the clustering operation
kclusters = 4
Toronto_grouped_clustering = merged_dfT.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=40).fit(Toronto_grouped_clustering)

# %%
# Adding clustering labels to the dataframe and merging dfToronto so we can add
#the coordinates of each neighborhood
merged_dfT.insert(0, 'Cluster Labels', kmeans.labels_)
dfToronto.columns=['Neighborhood', 'Borough', 'CrimesNumber', 'Longitude', 'Latitude']
Toronto_merged = dfToronto
Toronto_merged = Toronto_merged.join(merged_dfT.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged.head()
# Out:
#                    Neighborhood              Borough  CrimesNumber  Longitude  \
# 0               Agincourt North          Scarborough           363  -79.26707
# 1  Agincourt South-Malvern West          Scarborough           478  -79.26935
# 2                     Alderwood            Etobicoke           204  -79.54116
# 3                         Annex  Old City of Toronto           943  -79.40280
# 4             Banbury-Don Mills           North York           403  -79.34852
#
#    Latitude  Cluster Labels  TotalCrimes  ArtsEntertainmentCount  \
# 0  43.80930               3     0.114524                0.058824
# 1  43.78736               1     0.164985                0.058824
# 2  43.60496               3     0.044756                0.058824
# 3  43.66936               0     0.369022                0.235294
# 4  43.74041               3     0.132075                0.000000
#
#    CollegesCount  RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0       0.000000             0.175         0.03125                 0.074074
# 1       0.072289             0.250         0.09375                 0.111111
# 2       0.012048             0.050         0.00000                 0.148148
# 3       0.325301             0.325         0.21875                 0.333333
# 4       0.000000             0.025         0.00000                 0.037037
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                 0.000000            0.105263                 0.000
# 1                 0.043478            0.140351                 0.250
# 2                 0.000000            0.070175                 0.000
# 3                 0.130435            0.175439                 0.875
# 4                 0.000000            0.017544                 0.125
#
#    FoodShopCount
# 0       0.133333
# 1       0.133333
# 2       0.033333
# 3       0.200000
# 4       0.033333

# %%
# Cheching how many neighborhoods are in each cluster
Toronto_merged.groupby('Cluster Labels').count()
# Out:
#                 Neighborhood  Borough  CrimesNumber  Longitude  Latitude  \
# Cluster Labels
# 0                         17       17            17         17        17
# 1                         47       47            47         47        47
# 2                          2        2             2          2         2
# 3                         72       72            72         72        72
#
#                 TotalCrimes  ArtsEntertainmentCount  CollegesCount  \
# Cluster Labels
# 0                        17                      17             17
# 1                        47                      47             47
# 2                         2                       2              2
# 3                        72                      72             72
#
#                 RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# Cluster Labels
# 0                             17              17                       17
# 1                             47              47                       47
# 2                              2               2                        2
# 3                             72              72                       72
#
#                 GovernmentBuildingCount  MedicalCenterCount  \
# Cluster Labels
# 0                                    17                  17
# 1                                    47                  47
# 2                                     2                   2
# 3                                    72                  72
#
#                 SpiritualCenterCount  FoodShopCount
# Cluster Labels
# 0                                 17             17
# 1                                 47             47
# 2                                  2              2
# 3                                 72             72

# %% [markdown]
# ### London

# %%
# Setting the number of clusters and performing the clustering operation
kclusters = 4
London_grouped_clustering = merged_dfL.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=40).fit(London_grouped_clustering)

# %%
# Adding clustering labels to the dataframe and merging dfLondon so we can add
#the coordinates of each neighborhood
merged_dfL.insert(0, 'Cluster Labels', kmeans.labels_)
dfLondon.columns=['Neighborhood', 'Borough', 'CrimesNumber', 'Longitude', 'Latitude']
London_merged = dfLondon
London_merged = London_merged.join(merged_dfL.set_index('Neighborhood'), on='Neighborhood')
London_merged.head()
# Out:
#   Neighborhood                 Borough  CrimesNumber  Longitude   Latitude  \
# 0   Abbey Road             Westminster        1215.0  -0.127197  51.497657
# 1      Addison  Hammersmith and Fulham        2634.0  -0.212880  51.482600
# 2      Aldwych             Westminster           0.0  -0.118607  51.512653
# 3        Angel               Islington           0.0  -0.106260  51.532020
# 4      Archway               Islington           0.0  -0.134922  51.565748
#
#    Cluster Labels  TotalCrimes  ArtsEntertainmentCount  CollegesCount  \
# 0               3     0.037725                0.226667       0.064935
# 1               0     0.081783                0.040000       0.038961
# 2               1     0.000000                0.520000       1.000000
# 3               2     0.000000                0.186667       0.142857
# 4               0     0.000000                0.026667       0.051948
#
#    RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0              0.50            0.20                 0.542857
# 1              0.15            0.04                 0.228571
# 2              0.61            0.46                 0.742857
# 3              0.66            0.23                 0.542857
# 4              0.21            0.10                 0.114286
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                 0.871429            0.030769                0.5000
# 1                 0.000000            0.153846                0.2500
# 2                 0.171429            0.169231                0.5000
# 3                 0.057143            0.123077                0.1875
# 4                 0.071429            0.061538                0.3125
#
#    FoodShopCount
# 0       0.142857
# 1       0.061224
# 2       0.489796
# 3       0.448980
# 4       0.183673

# %%
# Checking how many neighborhoods are in each cluster
London_merged.groupby('Cluster Labels').count()
# Out:
#                 Neighborhood  Borough  CrimesNumber  Longitude  Latitude  \
# Cluster Labels
# 0                        168      168           168        168       168
# 1                         13       13            13         13        13
# 2                         73       73            73         73        73
# 3                          8        8             8          8         8
#
#                 TotalCrimes  ArtsEntertainmentCount  CollegesCount  \
# Cluster Labels
# 0                       168                     168            168
# 1                        13                      13             13
# 2                        73                      73             73
# 3                         8                       8              8
#
#                 RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# Cluster Labels
# 0                            168             168                      168
# 1                             13              13                       13
# 2                             73              73                       73
# 3                              8               8                        8
#
#                 GovernmentBuildingCount  MedicalCenterCount  \
# Cluster Labels
# 0                                   168                 168
# 1                                    13                  13
# 2                                    73                  73
# 3                                     8                   8
#
#                 SpiritualCenterCount  FoodShopCount
# Cluster Labels
# 0                                168            168
# 1                                 13             13
# 2                                 73             73
# 3                                  8              8

# %% [markdown]
# ## Creating new dataframes based on the cluster the neighborhoods belong to
# ### Toronto

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label0=Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[0] + list(range(5, Toronto_merged.shape[1]))]]
Label0.head()
# Out:
#                         Neighborhood  Cluster Labels  TotalCrimes  \
# 3                              Annex               0     0.369022
# 19  Cabbagetown-South St. James Town               0     0.144800
# 47                        Henry Farm               0     0.043879
# 58                     Junction Area               0     0.109258
# 61              Kensington-Chinatown               0     0.473892
#
#     ArtsEntertainmentCount  CollegesCount  RestaurantsCount  NightLifeCount  \
# 3                 0.235294       0.325301            0.3250         0.21875
# 19                0.411765       0.012048            0.3000         0.12500
# 47                1.000000       0.144578            0.1000         0.03125
# 58                0.529412       0.012048            0.3250         0.12500
# 61                1.000000       0.132530            0.6375         0.65625
#
#     OutdoorsRecreationCount  GovernmentBuildingCount  MedicalCenterCount  \
# 3                  0.333333                 0.130435            0.175439
# 19                 0.259259                 0.000000            0.070175
# 47                 0.111111                 0.086957            0.157895
# 58                 0.333333                 0.043478            0.035088
# 61                 0.296296                 0.086957            0.087719
#
#     SpiritualCenterCount  FoodShopCount
# 3                  0.875       0.200000
# 19                 0.375       0.266667
# 47                 0.125       0.100000
# 58                 0.250       0.166667
# 61                 0.750       0.966667

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label1=Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[0] + list(range(5, Toronto_merged.shape[1]))]]
Label1.head()
# Out:
#                     Neighborhood  Cluster Labels  TotalCrimes  \
# 1   Agincourt South-Malvern West               1     0.164985
# 5                 Bathurst Manor               1     0.065380
# 13                   Black Creek               1     0.286968
# 15          Briar Hill-Belgravia               1     0.092146
# 27        Corso Italia-Davenport               1     0.071961
#
#     ArtsEntertainmentCount  CollegesCount  RestaurantsCount  NightLifeCount  \
# 1                 0.058824       0.072289            0.2500         0.09375
# 5                 0.000000       0.000000            0.0125         0.00000
# 13                0.000000       0.012048            0.0375         0.00000
# 15                0.176471       0.000000            0.1000         0.15625
# 27                0.000000       0.012048            0.2125         0.28125
#
#     OutdoorsRecreationCount  GovernmentBuildingCount  MedicalCenterCount  \
# 1                  0.111111                 0.043478            0.140351
# 5                  0.148148                 0.000000            0.000000
# 13                 0.185185                 0.000000            0.035088
# 15                 0.074074                 0.086957            0.070175
# 27                 0.185185                 0.043478            0.070175
#
#     SpiritualCenterCount  FoodShopCount
# 1                   0.25       0.133333
# 5                   0.25       0.000000
# 13                  0.25       0.066667
# 15                  0.50       0.100000
# 27                  0.50       0.100000

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label2=Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[0] + list(range(5, Toronto_merged.shape[1]))]]
Label2.head()
# Out:
#              Neighborhood  Cluster Labels  TotalCrimes  \
# 6     Bay Street Corridor               2     0.795086
# 23  Church-Yonge Corridor               2     0.759105
#
#     ArtsEntertainmentCount  CollegesCount  RestaurantsCount  NightLifeCount  \
# 6                 0.411765       0.554217              0.85             0.5
# 23                0.823529       0.819277              1.00             1.0
#
#     OutdoorsRecreationCount  GovernmentBuildingCount  MedicalCenterCount  \
# 6                  1.000000                 1.000000            1.000000
# 23                 0.888889                 0.434783            0.298246
#
#     SpiritualCenterCount  FoodShopCount
# 6                   0.25       1.000000
# 23                  0.50       0.766667

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label3=Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[0] + list(range(5, Toronto_merged.shape[1]))]]
Label3.head()
# Out:
#             Neighborhood  Cluster Labels  TotalCrimes  ArtsEntertainmentCount  \
# 0        Agincourt North               3     0.114524                0.058824
# 2              Alderwood               3     0.044756                0.058824
# 4      Banbury-Don Mills               3     0.132075                0.000000
# 7        Bayview Village               3     0.090391                0.000000
# 8  Bayview Woods-Steeles               3     0.032032                0.000000
#
#    CollegesCount  RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0       0.000000             0.175         0.03125                 0.074074
# 2       0.012048             0.050         0.00000                 0.148148
# 4       0.000000             0.025         0.00000                 0.037037
# 7       0.000000             0.000         0.00000                 0.148148
# 8       0.000000             0.000         0.00000                 0.148148
#
#    GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                      0.0            0.105263                 0.000
# 2                      0.0            0.070175                 0.000
# 4                      0.0            0.017544                 0.125
# 7                      0.0            0.000000                 0.125
# 8                      0.0            0.017544                 0.000
#
#    FoodShopCount
# 0       0.133333
# 2       0.033333
# 4       0.033333
# 7       0.000000
# 8       0.000000

# %%
# Creating dataframes with the mean category values of each cluster
L0T=Label0.mean()
L0T=L0T.to_frame().reset_index().rename(columns={0:'Label 0'}, inplace=False)

L1T=Label1.mean()
L1T=L1T.to_frame().reset_index().rename(columns={0:'Label 1'}, inplace=False)

L2T=Label2.mean()
L2T=L2T.to_frame().reset_index().rename(columns={0:'Label 2'}, inplace=False)

L3T=Label3.mean()
L3T=L3T.to_frame().reset_index().rename(columns={0:'Label 3'}, inplace=False)

# %% [markdown]
# ### London

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label0=London_merged.loc[London_merged['Cluster Labels'] == 0, London_merged.columns[[0] + list(range(5, London_merged.shape[1]))]]
Label0.head()
# Out:
#                 Neighborhood  Cluster Labels  TotalCrimes  \
# 1                    Addison               0     0.081783
# 4                    Archway               0     0.000000
# 5   Avonmore and Brook Green               0     0.057255
# 9                  Battersea               0     0.000000
# 12                Bellingham               0     0.095166
#
#     ArtsEntertainmentCount  CollegesCount  RestaurantsCount  NightLifeCount  \
# 1                 0.040000       0.038961              0.15            0.04
# 4                 0.026667       0.051948              0.21            0.10
# 5                 0.066667       0.025974              0.26            0.13
# 9                 0.040000       0.000000              0.28            0.17
# 12                0.000000       0.000000              0.02            0.00
#
#     OutdoorsRecreationCount  GovernmentBuildingCount  MedicalCenterCount  \
# 1                  0.228571                 0.000000            0.153846
# 4                  0.114286                 0.071429            0.061538
# 5                  0.285714                 0.042857            0.076923
# 9                  0.142857                 0.000000            0.076923
# 12                 0.142857                 0.000000            0.030769
#
#     SpiritualCenterCount  FoodShopCount
# 1                 0.2500       0.061224
# 4                 0.3125       0.183673
# 5                 0.2500       0.122449
# 9                 0.2500       0.163265
# 12                0.0625       0.020408

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label1=London_merged.loc[London_merged['Cluster Labels'] == 1, London_merged.columns[[0] + list(range(5, London_merged.shape[1]))]]
Label1.head()
# Out:
#                       Neighborhood  Cluster Labels  TotalCrimes  \
# 2                          Aldwych               1     0.000000
# 7                         Bankside               1     0.000000
# 21                      Bloomsbury               1     0.243953
# 34  Camden Town with Primrose Hill               1     0.247865
# 39                      Cathedrals               1     0.209830
#
#     ArtsEntertainmentCount  CollegesCount  RestaurantsCount  NightLifeCount  \
# 2                 0.520000       1.000000              0.61            0.46
# 7                 0.293333       0.077922              0.69            0.42
# 21                0.586667       0.805195              0.43            0.28
# 34                0.093333       0.090909              0.78            0.65
# 39                0.146667       0.311688              1.00            0.73
#
#     OutdoorsRecreationCount  GovernmentBuildingCount  MedicalCenterCount  \
# 2                  0.742857                 0.171429            0.169231
# 7                  0.771429                 0.071429            0.046154
# 21                 0.600000                 0.057143            0.246154
# 34                 0.714286                 0.242857            0.107692
# 39                 0.742857                 0.057143            0.200000
#
#     SpiritualCenterCount  FoodShopCount
# 2                 0.5000       0.489796
# 7                 0.1875       0.755102
# 21                0.4375       0.387755
# 34                0.5625       0.244898
# 39                0.2500       1.000000

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label2=London_merged.loc[London_merged['Cluster Labels'] == 2, London_merged.columns[[0] + list(range(5, London_merged.shape[1]))]]
Label2.head()
# Out:
#    Neighborhood  Cluster Labels  TotalCrimes  ArtsEntertainmentCount  \
# 3         Angel               2     0.000000                0.186667
# 6        Balham               2     0.075543                0.093333
# 8     Barnsbury               2     0.115348                0.093333
# 10    Bayswater               2     0.069798                0.066667
# 11    Belgravia               2     0.000000                0.133333
#
#     CollegesCount  RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 3        0.142857              0.66            0.23                 0.542857
# 6        0.025974              0.32            0.10                 0.171429
# 8        0.051948              0.52            0.19                 0.342857
# 10       0.077922              0.46            0.17                 0.342857
# 11       0.038961              0.41            0.12                 0.457143
#
#     GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 3                  0.057143            0.123077                0.1875
# 6                  0.028571            0.107692                0.2500
# 8                  0.042857            0.076923                0.1250
# 10                 0.028571            0.107692                0.2500
# 11                 0.371429            0.046154                0.3125
#
#     FoodShopCount
# 3        0.448980
# 6        0.285714
# 8        0.285714
# 10       0.183673
# 11       0.102041

# %%
# Creating a label dataframe for each cluster and viewing the data in the cluster
Label3=London_merged.loc[London_merged['Cluster Labels'] == 3, London_merged.columns[[0] + list(range(5, London_merged.shape[1]))]]
Label3.head()
# Out:
#       Neighborhood  Cluster Labels  TotalCrimes  ArtsEntertainmentCount  \
# 0       Abbey Road               3     0.037725                0.226667
# 42   Charing Cross               3     0.000000                1.000000
# 47       Churchill               3     0.069146                0.293333
# 140     Maida Vale               3     0.043748                0.200000
# 149     New Eltham               3     0.000000                0.133333
#
#      CollegesCount  RestaurantsCount  NightLifeCount  OutdoorsRecreationCount  \
# 0         0.064935              0.50            0.20                 0.542857
# 42        0.142857              0.63            0.36                 0.942857
# 47        0.025974              0.19            0.16                 0.571429
# 140       0.077922              0.47            0.23                 0.542857
# 149       0.038961              0.31            0.16                 0.514286
#
#      GovernmentBuildingCount  MedicalCenterCount  SpiritualCenterCount  \
# 0                   0.871429            0.030769                0.5000
# 42                  0.571429            0.076923                0.1875
# 47                  1.000000            0.092308                0.4375
# 140                 0.814286            0.184615                0.5000
# 149                 0.485714            0.061538                0.3750
#
#      FoodShopCount
# 0         0.142857
# 42        0.489796
# 47        0.102041
# 140       0.183673
# 149       0.081633

# %%
# Creating dataframes with the mean category values of each cluster
L0L=Label0.mean()
L0L=L0L.to_frame().reset_index().rename(columns={0:'Label 0'}, inplace=False)

L1L=Label1.mean()
L1L=L1L.to_frame().reset_index().rename(columns={0:'Label 1'}, inplace=False)

L2L=Label2.mean()
L2L=L2L.to_frame().reset_index().rename(columns={0:'Label 2'}, inplace=False)

L3L=Label3.mean()
L3L=L3L.to_frame().reset_index().rename(columns={0:'Label 3'}, inplace=False)

# %% [markdown]
# ## Comparing the clusters and drawing conclusions
# ### Toronto

# %%
# Merging the mean values dataframes so the cluster information can be easily compared
labels_df=pd.merge(left=L0T, right=L1T, how='left', left_on='index', right_on='index')
labels_df=pd.merge(left=labels_df, right=L2T, how='left', left_on='index', right_on='index')
labels_df=pd.merge(left=labels_df, right=L3T, how='left', left_on='index', right_on='index')
labels_df=labels_df.drop(index=0)
labels_df
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 1               TotalCrimes  0.190822  0.138573  0.777095  0.151230
# 2    ArtsEntertainmentCount  0.411765  0.091364  0.617647  0.026144
# 3             CollegesCount  0.141035  0.017944  0.686747  0.008869
# 4          RestaurantsCount  0.372794  0.096011  0.925000  0.043750
# 5            NightLifeCount  0.262868  0.061170  0.750000  0.019097
# 6   OutdoorsRecreationCount  0.357298  0.124507  0.944444  0.102366
# 7   GovernmentBuildingCount  0.094629  0.027752  0.717391  0.019324
# 8        MedicalCenterCount  0.146543  0.061217  0.649123  0.042641
# 9      SpiritualCenterCount  0.580882  0.348404  0.375000  0.039931
# 10            FoodShopCount  0.264706  0.081560  0.883333  0.036111

# %%
# Neighborhoods with significant amounts of Spiritual Centers, Entertainment venues and
#Outdoors&Recreational venues, few NighLife and Government Buildings.
# I would categorize this cluster as close to downtown areas with average crime rates.
labels_df.sort_values('Label 0', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 9      SpiritualCenterCount  0.580882  0.348404  0.375000  0.039931
# 2    ArtsEntertainmentCount  0.411765  0.091364  0.617647  0.026144
# 4          RestaurantsCount  0.372794  0.096011  0.925000  0.043750
# 6   OutdoorsRecreationCount  0.357298  0.124507  0.944444  0.102366
# 10            FoodShopCount  0.264706  0.081560  0.883333  0.036111
# 5            NightLifeCount  0.262868  0.061170  0.750000  0.019097
# 1               TotalCrimes  0.190822  0.138573  0.777095  0.151230
# 8        MedicalCenterCount  0.146543  0.061217  0.649123  0.042641
# 3             CollegesCount  0.141035  0.017944  0.686747  0.008869
# 7   GovernmentBuildingCount  0.094629  0.027752  0.717391  0.019324

# %%
# Neighborhoods with many Spiritual Centers, Outdoors&Recreational venues and
#Restaurants, however not many Night Life venues.
# I would categorize this cluster as dense residential neighborhoods with high crime rates.
labels_df.sort_values('Label 1', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 9      SpiritualCenterCount  0.580882  0.348404  0.375000  0.039931
# 1               TotalCrimes  0.190822  0.138573  0.777095  0.151230
# 6   OutdoorsRecreationCount  0.357298  0.124507  0.944444  0.102366
# 4          RestaurantsCount  0.372794  0.096011  0.925000  0.043750
# 2    ArtsEntertainmentCount  0.411765  0.091364  0.617647  0.026144
# 10            FoodShopCount  0.264706  0.081560  0.883333  0.036111
# 8        MedicalCenterCount  0.146543  0.061217  0.649123  0.042641
# 5            NightLifeCount  0.262868  0.061170  0.750000  0.019097
# 7   GovernmentBuildingCount  0.094629  0.027752  0.717391  0.019324
# 3             CollegesCount  0.141035  0.017944  0.686747  0.008869

# %%
# Neighborhoods with significant amounts of Recreational venues, Restaurants and
#Night Live venues venues, also significant amount of Govermnment Buildings.
# I would categorize this cluster as City Center/Downtown areas with average amount of crimes.
labels_df.sort_values('Label 2', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 6   OutdoorsRecreationCount  0.357298  0.124507  0.944444  0.102366
# 4          RestaurantsCount  0.372794  0.096011  0.925000  0.043750
# 10            FoodShopCount  0.264706  0.081560  0.883333  0.036111
# 1               TotalCrimes  0.190822  0.138573  0.777095  0.151230
# 5            NightLifeCount  0.262868  0.061170  0.750000  0.019097
# 7   GovernmentBuildingCount  0.094629  0.027752  0.717391  0.019324
# 3             CollegesCount  0.141035  0.017944  0.686747  0.008869
# 8        MedicalCenterCount  0.146543  0.061217  0.649123  0.042641
# 2    ArtsEntertainmentCount  0.411765  0.091364  0.617647  0.026144
# 9      SpiritualCenterCount  0.580882  0.348404  0.375000  0.039931

# %%
# Neighborhoods with many Restaurants, Medical Centers and Outdoors&Recreational
#venues, only some Government Buildings and not many Night Life venues
# I would categorize this cluster as densely populated neighborhoods with very high crime rates.
labels_df.sort_values('Label 3', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 1               TotalCrimes  0.190822  0.138573  0.777095  0.151230
# 6   OutdoorsRecreationCount  0.357298  0.124507  0.944444  0.102366
# 4          RestaurantsCount  0.372794  0.096011  0.925000  0.043750
# 8        MedicalCenterCount  0.146543  0.061217  0.649123  0.042641
# 9      SpiritualCenterCount  0.580882  0.348404  0.375000  0.039931
# 10            FoodShopCount  0.264706  0.081560  0.883333  0.036111
# 2    ArtsEntertainmentCount  0.411765  0.091364  0.617647  0.026144
# 7   GovernmentBuildingCount  0.094629  0.027752  0.717391  0.019324
# 5            NightLifeCount  0.262868  0.061170  0.750000  0.019097
# 3             CollegesCount  0.141035  0.017944  0.686747  0.008869

# %% [markdown]
# ### London

# %%
# Merging the mean values dataframes so the cluster information can be easily compared
labels_df=pd.merge(left=L0L, right=L1L, how='left', left_on='index', right_on='index')
labels_df=pd.merge(left=labels_df, right=L2L, how='left', left_on='index', right_on='index')
labels_df=pd.merge(left=labels_df, right=L3L, how='left', left_on='index', right_on='index')
labels_df=labels_df.drop(index=0)
labels_df
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 1               TotalCrimes  0.076920  0.091409  0.077995  0.039087
# 2    ArtsEntertainmentCount  0.037143  0.366154  0.118904  0.316667
# 3             CollegesCount  0.033472  0.497502  0.119374  0.063312
# 4          RestaurantsCount  0.119226  0.716923  0.439726  0.396250
# 5            NightLifeCount  0.053810  0.525385  0.199452  0.201250
# 6   OutdoorsRecreationCount  0.156973  0.738462  0.398434  0.610714
# 7   GovernmentBuildingCount  0.020238  0.120879  0.060274  0.739286
# 8        MedicalCenterCount  0.060714  0.190533  0.104953  0.092308
# 9      SpiritualCenterCount  0.142113  0.500000  0.253425  0.406250
# 10            FoodShopCount  0.086127  0.613815  0.249371  0.163265

# %%
# Neighborhoods with significant amounts of Spiritual Centers, Outdoors&Recreational and
#Restaurant venues, very few Government Buildings and Colleges, however they have a significant amount of crimes.
# I would categorize this cluster as dense populated areas, prone to criminal activities. 
labels_df.sort_values('Label 0', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 6   OutdoorsRecreationCount  0.156973  0.738462  0.398434  0.610714
# 9      SpiritualCenterCount  0.142113  0.500000  0.253425  0.406250
# 4          RestaurantsCount  0.119226  0.716923  0.439726  0.396250
# 10            FoodShopCount  0.086127  0.613815  0.249371  0.163265
# 1               TotalCrimes  0.076920  0.091409  0.077995  0.039087
# 8        MedicalCenterCount  0.060714  0.190533  0.104953  0.092308
# 5            NightLifeCount  0.053810  0.525385  0.199452  0.201250
# 2    ArtsEntertainmentCount  0.037143  0.366154  0.118904  0.316667
# 3             CollegesCount  0.033472  0.497502  0.119374  0.063312
# 7   GovernmentBuildingCount  0.020238  0.120879  0.060274  0.739286

# %%
# Neighborhoods with many Restaurants, Night Life venues and Outdoors&Recreational
#venues, not many Government Buildings.
# I would categorize this cluster as close do Downtown areas, with very few crimes reported.
labels_df.sort_values('Label 1', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 6   OutdoorsRecreationCount  0.156973  0.738462  0.398434  0.610714
# 4          RestaurantsCount  0.119226  0.716923  0.439726  0.396250
# 10            FoodShopCount  0.086127  0.613815  0.249371  0.163265
# 5            NightLifeCount  0.053810  0.525385  0.199452  0.201250
# 9      SpiritualCenterCount  0.142113  0.500000  0.253425  0.406250
# 3             CollegesCount  0.033472  0.497502  0.119374  0.063312
# 2    ArtsEntertainmentCount  0.037143  0.366154  0.118904  0.316667
# 8        MedicalCenterCount  0.060714  0.190533  0.104953  0.092308
# 7   GovernmentBuildingCount  0.020238  0.120879  0.060274  0.739286
# 1               TotalCrimes  0.076920  0.091409  0.077995  0.039087

# %%
# Neighborhoods with significant amounts of Spiritual Centers, Restaurants and
#Outdoors&Recreational venues, not many Government Buildings.
# I would categorize this cluster as densely populated residential neighborhoods with low crime rates.
labels_df.sort_values('Label 2', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 4          RestaurantsCount  0.119226  0.716923  0.439726  0.396250
# 6   OutdoorsRecreationCount  0.156973  0.738462  0.398434  0.610714
# 9      SpiritualCenterCount  0.142113  0.500000  0.253425  0.406250
# 10            FoodShopCount  0.086127  0.613815  0.249371  0.163265
# 5            NightLifeCount  0.053810  0.525385  0.199452  0.201250
# 3             CollegesCount  0.033472  0.497502  0.119374  0.063312
# 2    ArtsEntertainmentCount  0.037143  0.366154  0.118904  0.316667
# 8        MedicalCenterCount  0.060714  0.190533  0.104953  0.092308
# 1               TotalCrimes  0.076920  0.091409  0.077995  0.039087
# 7   GovernmentBuildingCount  0.020238  0.120879  0.060274  0.739286

# %%
# Neighborhoods with many Government Buildings, Outdoors&Recreational venues 
#and Spiritual Centers.
# I would categorize this cluster as City Center/Downtown neighborhoods with very low crime rates.
labels_df.sort_values('Label 3', ascending=False)
# Out:
#                       index   Label 0   Label 1   Label 2   Label 3
# 7   GovernmentBuildingCount  0.020238  0.120879  0.060274  0.739286
# 6   OutdoorsRecreationCount  0.156973  0.738462  0.398434  0.610714
# 9      SpiritualCenterCount  0.142113  0.500000  0.253425  0.406250
# 4          RestaurantsCount  0.119226  0.716923  0.439726  0.396250
# 2    ArtsEntertainmentCount  0.037143  0.366154  0.118904  0.316667
# 5            NightLifeCount  0.053810  0.525385  0.199452  0.201250
# 10            FoodShopCount  0.086127  0.613815  0.249371  0.163265
# 8        MedicalCenterCount  0.060714  0.190533  0.104953  0.092308
# 3             CollegesCount  0.033472  0.497502  0.119374  0.063312
# 1               TotalCrimes  0.076920  0.091409  0.077995  0.039087

# %% [markdown]
# ## Map of Toronto with the neighborhoods clusters

# %%
#Creating the Toronto map with the neighborhoods clusters imposed on top
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# Color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Markers for the map
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_27476dc66c3e473ebf6b1ca9e3a39c9f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_27476dc66c3e473ebf6b1ca9e3a39c9f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_27476dc66c3e473ebf6b1ca9e3a39c9f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_27476dc66c3e473ebf6b1ca9e3a39c9f%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B%5B51.49765730513152%2C%2051.48260000000005%2C%2051.51265251684556%2C%2051.532020000000045%2C%2051.56574780726418%2C%2051.49620224997504%2C%2051.44421949800005%2C%2051.50816355244705%2C%2051.536488687022775%2C%2051.459230038551254%2C%2051.51229302300004%2C%2051.494858453208806%2C%2051.42737789200004%2C%2051.54 ...

# %% [markdown]
# ## Map of London with the neighborhoods clusters

# %%
#Creating the Toronto map with the neighborhoods clusters imposed on top
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# Color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Markers for the map
markers_colors = []
for lat, lon, poi, cluster in zip(London_merged['Latitude'], London_merged['Longitude'], London_merged['Neighborhood'], London_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_44e6d8c616a3432ebb09e4f8f10881e2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_44e6d8c616a3432ebb09e4f8f10881e2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_44e6d8c616a3432ebb09e4f8f10881e2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_44e6d8c616a3432ebb09e4f8f10881e2%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B%5B51.49765730513152%2C%2051.48260000000005%2C%2051.51265251684556%2C%2051.532020000000045%2C%2051.56574780726418%2C%2051.49620224997504%2C%2051.44421949800005%2C%2051.50816355244705%2C%2051.536488687022775%2C%2051.459230038551254%2C%2051.51229302300004%2C%2051.494858453208806%2C%2051.42737789200004%2C%2051.54 ...
